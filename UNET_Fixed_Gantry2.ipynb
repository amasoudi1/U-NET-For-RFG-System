# %% [markdown]
# <a href="https://colab.research.google.com/github/amasoudi1/U-NET-For-RFG-System/blob/master/UNET_Fixed_Gantry2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pyyaml  # pyyaml is an optional
# !pip install -U -q PyDrive  # PyDrive you can upload/download read and write data
# Out:
#      |████████████████████████████████| 993kB 3.3MB/s
#   Building wheel for PyDrive (setup.py) ... done

# %%
#import tensorflow as tf
#from tensorflow.keras import layers
#from tensorflow.python.client import device_lib


#print(tf.VERSION)
#print(tf.keras.__version__)
#device_lib.list_local_devices()

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd /content/gdrive/'My Drive'/'Colab Notebooks'/
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
ls
# Out:
#  bagdata/                            test_data_128/
# 'Copy of UNET_Fixed_Gantry3.ipynb'   test_images_128/
#  data_label/                         test_images_norm_128/
#  data_label_noisy/                   test_label_conv_rfg_100/
#  data_noisy/                         test_labels_128/
#  data_reconstruction/                test_labels_norm_128/
#  data_reconstruction_noisy/          test_rec_conv_rfg_100/
#  FbpConvNet.ipynb                    train_data/
#  model100.h5                         train_data_128/
#  model100v2.h5                       trainHistoryDict
#  model100v3.h5                       trainHistoryDictV3
#  model100v4.h5                       train_images_128/
#  model100v5.h5                       train_images_norm_128/
#  model1.h5                           training/
#  model.h5                            train_label_conv_rfg_100/
#  rfg.h5                              train_labels_128/
#  rfg_v1_noisy.h5                     train_labels_norm_128/
#  rfg_v2.h5                           train_rec_conv_rfg_100/
#  rfg_v3.h5                           UNET_Fixed_Gantry2.ipynb
#  rfg_v4.h5                           UNET_Fixed_Gantry3.ipynb
#  steps.png                           u-net.png
#  test_data/                          Untitled0.ipynb

# %%
import os
import sys

try:
 device_name = os.environ['COLAB_TPU_ADDR']
 TPU_ADDRESS = 'grpc://' + device_name
 print('Found TPU at: {}'.format(TPU_ADDRESS))
except KeyError:
 print('TPU not found')
# Out:
# TPU not found

# %%
#from tensorflow.keras.models import *
#from tensorflow.keras.layers import *
#from tensorflow.keras.optimizers import *
#from tensorflow.keras.initializers import *
#from tf.keras.callbacks import ModelCheckpoint, LearningRateScheduler
#from tf.keras import backend as keras

from keras.models import Model
from keras.layers import *
from keras.optimizers import *
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
import keras.backend as K
from keras.callbacks import LearningRateScheduler, ModelCheckpoint ,Callback
from keras.initializers import *

import cv2
import numpy as np
import scipy.io as sc
import os
import sys
from sklearn.utils import shuffle
#from scipy.ndimage import imread
from imageio import imread
#from scipy.misc import imresize
import matplotlib.pyplot as plt

#np.random.seed(0)
#tf.set_random_seed(0)
#print(tf.VERSION)
#print(tf.keras.__version__)


train_images = np.zeros(shape=(450,100,100,1))
train_labels = np.zeros(shape=(450,100,100,1))

test_images = np.zeros(shape=(50,100,100,1))
test_labels = np.zeros(shape=(50,100,100,1))

indx = np.arange(500)
np.random.shuffle(indx)
print(indx[450:500])

#################################################### --- get training data ---
images_location = "./data_reconstruction_noisy/"
labels_location = "./data_label_noisy/"

for i in range(450):    
    image_temp = sc.loadmat(images_location + str(4*indx[i]+1) + ".mat")    
    train_images[i,:,:]   = np.expand_dims(np.array(image_temp['r']),axis=2)
    
    label_temp = sc.loadmat(labels_location + str(4*indx[i]+1) + ".mat")    
    train_labels[i,:,:]   = np.expand_dims(np.array(label_temp['t']),axis=2)
    
                
#################################################### --- get test data ---
      
counter = 0  
for i in range(450,500):      
    image_temp = sc.loadmat(images_location + str(4*indx[i]+1) + ".mat")    
    test_images[counter,:,:]   = np.expand_dims(np.array(image_temp['r']),axis=2)
    
    label_temp = sc.loadmat(labels_location + str(4*indx[i]+1) + ".mat")    
    test_labels[counter,:,:]   = np.expand_dims(np.array(label_temp['t']),axis=2)
    counter += 1
      
#train_images = 1*(train_images - train_images.min()) / (train_images.max() - train_images.min())
#train_labels = 1*(train_labels - train_labels.min()) / (train_labels.max() - train_labels.min())      
      
      
########################################################### Adjusting Contrast
def adjust_gamma(image, gamma=1.0):
   invGamma = 1.0 / gamma
   table = np.array([
      ((i / 255.0) ** invGamma) * 255
      for i in np.arange(0, 256)])
   return cv2.LUT(image.astype(np.uint8), table.astype(np.uint8))

########################################################### sample training data  
fix, ax = plt.subplots(4,2, figsize=(4,10))
for i in range(4):
    #ax[i,0].imshow(train_images[i,:,:,0], cmap='gray')
    ax[i,0].imshow(adjust_gamma((train_images[i,:,:,0]), 1), cmap='gray')    
    ax[i,1].imshow(adjust_gamma((train_labels[i,:,:,0]), 1.5), cmap='gray')

ax[0,0].set_title('Input')
ax[0,1].set_title('Ground Truth')

plt.show()

################### Left Column : sample input, Right Column : sample label
# Out:
# Using TensorFlow backend.
# [176 291 111 400 118   5 283  10 210 325  81 113 376 462 174 438 281 276
#  193 312 146 264  72  43   9 168  27 443 490  90 491 476 287 406 290 395
#   71 493  73 424 172 192  94 159 481 439 343 152  89  35]

# %%
######################################################## Defining The U-Net
SEED = 42
#initializer = RandomNormal(mean=0.0, stddev=0.05, seed = SEED) 
initializer = glorot_normal(seed = SEED) 
inputs = Input(shape=(100,100,1))  # Returns a placeholder tensor

### Layers :
# LEVEL 1
L10 = Conv2D(1, (1, 1), activation='relu', padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(inputs)
L11 = Conv2D(64, (1, 1), activation='relu', padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L10)
L11 = BatchNormalization()(L11)
L12 = Conv2D(64, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L11)
L12 = BatchNormalization()(L12)
L13 = Conv2D(64, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L12)
L13 = BatchNormalization()(L13)

# LEVEL 2
L20 = MaxPooling2D(pool_size=(2, 2), padding='valid')(L13)
L21 = Conv2D(128, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L20)
L21 = BatchNormalization()(L21)
L22 = Conv2D(128, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L21)
L22 = BatchNormalization()(L22)

# LEVEL 3
L30 = MaxPooling2D(pool_size=(2, 2), padding='valid')(L22)
L31 = Conv2D(256, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L30)
L31 = BatchNormalization()(L31)
L32 = Conv2D(256, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L31)
L32 = BatchNormalization()(L32)

# LEVEL 4
L40 = MaxPooling2D(pool_size=(2, 2), padding='valid')(L32)
L41 = Conv2D(512, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L40)
L41 = BatchNormalization()(L41)
L42 = Conv2D(512, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L41)
L42 = BatchNormalization()(L42)

# LEVEL 5
L50 = MaxPooling2D(pool_size=(2, 2), padding='valid')(L42)
L51 = Conv2D(1024, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L50)
L51 = BatchNormalization()(L51)
L52 = Conv2D(1024, (3, 3), activation='relu' ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L51)
L52 = BatchNormalization()(L52)

# LEVEL 4
L43_in = Conv2DTranspose(256, (3, 3), activation='relu' , strides=(2, 2) ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L52)
#L43_in = UpSampling2D(size=(2,2))(L52)
L43_in = BatchNormalization()(L43_in)
L43 = Conv2D(512, (3, 3), activation='relu' ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(concatenate([L42,L43_in], axis = 3))
L43 = BatchNormalization()(L43)
L44 = Conv2D(512, (3, 3), activation='relu' ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L43)
L44 = BatchNormalization()(L44)

# LEVEL 3
L33_in = Conv2DTranspose(128, (3, 3), activation='relu', strides=(2, 2) ,padding='valid',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L44)
#L33_in = UpSampling2D(size=(2,2))(L44)
L33_in = BatchNormalization()(L33_in)
L33 = Conv2D(256, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(concatenate([L32,L33_in], axis = 3))
L33 = BatchNormalization()(L33)
L34 = Conv2D(256, (3, 3), activation='relu' ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L33)
L34 = BatchNormalization()(L34)

# LEVEL 2
L23_in = Conv2DTranspose(64, (3, 3), activation='relu' , strides=(2, 2) ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L34)
#L23_in = UpSampling2D(size=(2,2))(L34)
L23_in = BatchNormalization()(L23_in)
L23 = Conv2D(128, (3, 3), activation='relu' ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(concatenate([L22,L23_in], axis = 3))
L23 = BatchNormalization()(L23)
L24 = Conv2D(128, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L23)
L24 = BatchNormalization()(L24)

# LEVEL 1
L14_in = Conv2DTranspose(32, (3, 3), activation='relu' , strides=(2, 2) ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L24)
#L14_in = UpSampling2D(size=(2,2))(L24)
L14_in = BatchNormalization()(L14_in)
L14 = Conv2D(64, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(concatenate([L13,L14_in], axis = 3))
L14 = BatchNormalization()(L14)
L15 = Conv2D(64, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L14)
L15 = BatchNormalization()(L15)
L16 = Conv2D(1, (1, 1), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L15)
feed_forward = Add()([L10,L16])
L17 = Conv2D(1, (1, 1), padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(feed_forward)


model = Model(inputs=inputs, outputs=L17)
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0703 21:10:16.293004 140675202287488 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0703 21:10:16.339352 140675202287488 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0703 21:10:16.346378 140675202287488 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0703 21:10:16.392084 140675202287488 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0703 21:10:16.393126 140675202287488 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0703 21:10:19.220271 140675202287488 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0703 21:10:19.441261 140675202287488 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 100, 100, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 100, 100, 1)  2           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 100, 100, 64) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100, 100, 64) 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 100, 100, 64) 36928       batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 100, 100, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 100, 100, 64) 36928       batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 100, 100, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 50, 50, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 50, 50, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 50, 50, 128)  147584      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 50, 50, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 25, 25, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 25, 25, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 25, 25, 256)  590080      batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 25, 25, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 12, 12, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 12, 12, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 12, 12, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 12, 12, 512)  2359808     batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 12, 12, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 6, 6, 512)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 6, 6, 1024)   4719616     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 6, 6, 1024)   4096        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 6, 6, 1024)   9438208     batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 6, 6, 1024)   4096        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 12, 12, 256)  2359552     batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 12, 12, 256)  1024        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 768)  0           batch_normalization_9[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 12, 12, 512)  3539456     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 12, 12, 512)  2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 12, 12, 512)  2359808     batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 12, 12, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 25, 25, 128)  589952      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 25, 25, 128)  512         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 25, 25, 384)  0           batch_normalization_7[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 25, 25, 256)  884992      concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 25, 25, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 25, 25, 256)  590080      batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 25, 25, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 50, 50, 64)   147520      batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 50, 50, 64)   256         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 50, 50, 192)  0           batch_normalization_5[0][0]
#                                                                  batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 50, 50, 128)  221312      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 50, 50, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 50, 50, 128)  147584      batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 50, 50, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 100, 100, 32) 36896       batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 100, 100, 32) 128         conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 100, 100, 96) 0           batch_normalization_3[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 100, 100, 64) 55360       concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 100, 100, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 100, 100, 64) 36928       batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 100, 100, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 100, 100, 1)  65          batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 100, 100, 1)  0           conv2d_1[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 100, 100, 1)  2           add_1[0][0]
# ==================================================================================================
# Total params: 29,873,701
# Trainable params: 29,860,837
# Non-trainable params: 12,864
# __________________________________________________________________________________________________

# %%
################################################# Data Augmentation : Only Horizontal and Vertical Flip
def my_generator(x_train, y_train, batch_size):
    data_generator = ImageDataGenerator(horizontal_flip = True, vertical_flip = True).flow(x_train, x_train, batch_size, seed=SEED)
    mask_generator = ImageDataGenerator(horizontal_flip = True, vertical_flip = True).flow(y_train, y_train, batch_size, seed=SEED)
    while True:
        x_batch, _ = data_generator.next()
        y_batch, _ = mask_generator.next()
        yield x_batch, y_batch

# %%
############################################## sample training data after augmentation
image_batch, mask_batch = next(my_generator(train_images, train_labels, 5))
fix, ax = plt.subplots(4,2, figsize=(5,10))
for i in range(4):
    #ax[i,0].imshow(image_batch[i,:,:,0], cmap='gray')
    #ax[i,1].imshow(mask_batch[i,:,:,0], cmap='gray')
    ax[i,0].imshow(adjust_gamma((image_batch[i,:,:,0]), 0.6), cmap='gray')    
    ax[i,1].imshow(adjust_gamma((mask_batch[i,:,:,0]), 1.5), cmap='gray')    
ax[0,0].set_title('Input')
ax[0,1].set_title('Ground Truth')    
plt.show()
################### Left Column : sample input, Right Column : sample label

# %%
############################################### Training Using The optimizer

#sgd = SGD(lr=1e-4, momentum=0.99, nesterov = True, clipvalue=0.01)
#sgd = SGD(lr=1, momentum=0.99, clipvalue=0.01)
#sgd = tf.train.MomentumOptimizer(learning_rate = 0.01, momentum=0.99)

#class LossHistory(Callback):
#    def on_train_begin(self, logs={}):
#        self.losses = []
#
#    def on_batch_end(self, batch, logs={}):
#        self.losses.append(logs.get('loss'))

model.compile(Adam(lr = 0.01), loss='mean_squared_error', metrics=['mean_absolute_error'])

weight_saver = ModelCheckpoint('./rfg_v1_noisy.h5', monitor='val_loss',
                               save_best_only=True, save_weights_only=True)
# Out:
# W0703 21:10:22.155637 140675202287488 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#model.load_weights('rfg.h5')
#model.compile(Adam(lr = 0.01), loss='mean_squared_error', metrics=['mean_absolute_error'])
#loss, acc = model.evaluate(train_images,train_labels)
#print(loss)
#print(acc)

#history = LossHistory()
#hist = model.fit(train_images, train_labels, batch_size = 32, epochs = 2000, validation_data = (test_images,test_labels), 
#          shuffle = True ,verbose = 1, callbacks = [weight_saver,history])#, annealer])

hist = model.fit_generator(my_generator(train_images, train_labels, 32), validation_data = (test_images,test_labels),
                           epochs=1000, verbose=2, shuffle=True,
                           steps_per_epoch = 64,
                           callbacks = [weight_saver])#, annealer])
# Out:
# Epoch 1/1000
#  - 36s - loss: 88116.9783 - mean_absolute_error: 255.0292 - val_loss: 35913.6019 - val_mean_absolute_error: 123.8411
# Epoch 2/1000
#  - 23s - loss: 36838.4634 - mean_absolute_error: 105.4206 - val_loss: 33023.9750 - val_mean_absolute_error: 99.6315
# Epoch 3/1000
#  - 23s - loss: 36712.4855 - mean_absolute_error: 103.0000 - val_loss: 32427.2180 - val_mean_absolute_error: 95.1712
# Epoch 4/1000
#  - 22s - loss: 37215.3631 - mean_absolute_error: 104.3405 - val_loss: 32296.3928 - val_mean_absolute_error: 97.1022
# Epoch 5/1000
#  - 23s - loss: 35493.6448 - mean_absolute_error: 99.6762 - val_loss: 32279.4670 - val_mean_absolute_error: 95.6300
# Epoch 6/1000
#  - 23s - loss: 37414.6930 - mean_absolute_error: 103.2275 - val_loss: 31975.1108 - val_mean_absolute_error: 95.4864
# Epoch 7/1000
#  - 23s - loss: 35306.5513 - mean_absolute_error: 98.1082 - val_loss: 31862.6303 - val_mean_absolute_error: 94.3304
# Epoch 8/1000
#  - 22s - loss: 36908.3591 - mean_absolute_error: 100.9381 - val_loss: 31346.7531 - val_mean_absolute_error: 90.2736
# Epoch 9/1000
#  - 23s - loss: 36037.3643 - mean_absolute_error: 98.5823 - val_loss: 31507.5180 - val_mean_absolute_error: 93.2677
# Epoch 10/1000
#  - 23s - loss: 35452.7319 - mean_absolute_error: 97.4137 - val_loss: 31091.6767 - val_mean_absolute_error: 89.3291
# Epoch 11/1000
#  - 23s - loss: 34252.5807 - mean_absolute_error: 93.9948 - val_loss: 31115.9781 - val_mean_absolute_error: 91.9669
# Epoch 12/1000
#  - 22s - loss: 35736.4534 - mean_absolute_error: 96.5104 - val_loss: 30804.7623 - val_mean_absolute_error: 89.0880
# Epoch 13/1000
#  - 23s - loss: 35469.9518 - mean_absolute_error: 96.3713 - val_loss: 30619.2999 - val_mean_absolute_error: 89.4867
# Epoch 14/1000
#  - 23s - loss: 34595.0964 - mean_absolute_error: 94.4831 - val_loss: 30583.8638 - val_mean_absolute_error: 90.1276
# Epoch 15/1000
#  - 23s - loss: 34720.5279 - mean_absolute_error: 95.9715 - val_loss: 30343.9841 - val_mean_absolute_error: 86.6792
# Epoch 16/1000
#  - 23s - loss: 34515.5660 - mean_absolute_error: 93.5601 - val_loss: 30307.3763 - val_mean_absolute_error: 88.8407
# Epoch 17/1000
#  - 23s - loss: 34359.0111 - mean_absolute_error: 93.2903 - val_loss: 30046.5297 - val_mean_absolute_error: 87.0357
# Epoch 18/1000
#  - 23s - loss: 35213.4708 - mean_absolute_error: 95.8067 - val_loss: 30317.6423 - val_mean_absolute_error: 89.5104
# Epoch 19/1000
#  - 22s - loss: 34576.6555 - mean_absolute_error: 94.0923 - val_loss: 31725.6437 - val_mean_absolute_error: 100.4332
# Epoch 20/1000
#  - 23s - loss: 34027.8527 - mean_absolute_error: 94.6824 - val_loss: 31817.1222 - val_mean_absolute_error: 106.4502
# Epoch 21/1000
#  - 23s - loss: 32776.3151 - mean_absolute_error: 90.6720 - val_loss: 29884.0465 - val_mean_absolute_error: 88.7304
# Epoch 22/1000
#  - 23s - loss: 33407.4437 - mean_absolute_error: 90.9961 - val_loss: 29594.9884 - val_mean_absolute_error: 86.3480
# Epoch 23/1000
#  - 22s - loss: 33086.3205 - mean_absolute_error: 91.8521 - val_loss: 29709.5337 - val_mean_absolute_error: 88.0169
# Epoch 24/1000
#  - 23s - loss: 33793.1282 - mean_absolute_error: 92.1147 - val_loss: 29273.9412 - val_mean_absolute_error: 84.2944
# Epoch 25/1000
#  - 23s - loss: 33145.7936 - mean_absolute_error: 90.9446 - val_loss: 29473.3677 - val_mean_absolute_error: 88.8036
# Epoch 26/1000
#  - 23s - loss: 32810.8320 - mean_absolute_error: 90.1960 - val_loss: 29082.9802 - val_mean_absolute_error: 84.4953
# Epoch 27/1000
#  - 22s - loss: 33884.7989 - mean_absolute_error: 94.8040 - val_loss: 33863.0200 - val_mean_absolute_error: 95.8000
# Epoch 28/1000
#  - 23s - loss: 32382.6247 - mean_absolute_error: 91.1864 - val_loss: 29807.2886 - val_mean_absolute_error: 94.3366
# Epoch 29/1000
#  - 23s - loss: 35243.2566 - mean_absolute_error: 97.9935 - val_loss: 33368.6155 - val_mean_absolute_error: 110.4160
# Epoch 30/1000
#  - 23s - loss: 33239.3094 - mean_absolute_error: 92.9435 - val_loss: 28737.5913 - val_mean_absolute_error: 81.6727
# Epoch 31/1000
#  - 23s - loss: 33698.9673 - mean_absolute_error: 94.2344 - val_loss: 28752.7809 - val_mean_absolute_error: 83.0587
# Epoch 32/1000
#  - 23s - loss: 32354.4620 - mean_absolute_error: 89.1801 - val_loss: 28779.5784 - val_mean_absolute_error: 85.4484
# Epoch 33/1000
#  - 23s - loss: 32314.3209 - mean_absolute_error: 89.8426 - val_loss: 29045.3774 - val_mean_absolute_error: 88.9840
# Epoch 34/1000
#  - 22s - loss: 33041.6407 - mean_absolute_error: 91.8532 - val_loss: 28653.1799 - val_mean_absolute_error: 84.5902
# Epoch 35/1000
#  - 23s - loss: 32322.8352 - mean_absolute_error: 90.1125 - val_loss: 28517.3347 - val_mean_absolute_error: 84.7126
# Epoch 36/1000
#  - 23s - loss: 32269.7946 - mean_absolute_error: 88.9877 - val_loss: 28350.6725 - val_mean_absolute_error: 83.5198
# Epoch 37/1000
#  - 23s - loss: 33507.3324 - mean_absolute_error: 92.8799 - val_loss: 31204.6094 - val_mean_absolute_error: 108.7215
# Epoch 38/1000
#  - 22s - loss: 32041.0686 - mean_absolute_error: 89.2059 - val_loss: 28463.7702 - val_mean_absolute_error: 86.9458
# Epoch 39/1000
#  - 23s - loss: 32081.4528 - mean_absolute_error: 90.1657 - val_loss: 28280.3797 - val_mean_absolute_error: 85.1163
# Epoch 40/1000
#  - 23s - loss: 32783.6727 - mean_absolute_error: 92.9619 - val_loss: 29538.3091 - val_mean_absolute_error: 92.0281
# Epoch 41/1000
#  - 23s - loss: 31171.1233 - mean_absolute_error: 86.7520 - val_loss: 27765.6415 - val_mean_absolute_error: 80.0181
# Epoch 42/1000
#  - 22s - loss: 31925.4373 - mean_absolute_error: 90.0072 - val_loss: 27946.3824 - val_mean_absolute_error: 83.0244
# Epoch 43/1000
#  - 23s - loss: 32224.4566 - mean_absolute_error: 89.9380 - val_loss: 28045.9412 - val_mean_absolute_error: 81.4902
# Epoch 44/1000
#  - 23s - loss: 31834.4397 - mean_absolute_error: 89.0762 - val_loss: 27544.3487 - val_mean_absolute_error: 79.0770
# Epoch 45/1000
#  - 23s - loss: 31711.0308 - mean_absolute_error: 90.4786 - val_loss: 27476.6798 - val_mean_absolute_error: 78.6156
# Epoch 46/1000
#  - 23s - loss: 31379.1560 - mean_absolute_error: 88.6425 - val_loss: 28007.9834 - val_mean_absolute_error: 87.1042
# Epoch 47/1000
#  - 23s - loss: 30943.2585 - mean_absolute_error: 86.7770 - val_loss: 27982.3772 - val_mean_absolute_error: 87.7569
# Epoch 48/1000
#  - 23s - loss: 31368.8343 - mean_absolute_error: 87.0351 - val_loss: 27604.4253 - val_mean_absolute_error: 83.9386
# Epoch 49/1000
#  - 22s - loss: 31469.0705 - mean_absolute_error: 87.6724 - val_loss: 27071.7566 - val_mean_absolute_error: 77.7084
# Epoch 50/1000
#  - 23s - loss: 30226.8791 - mean_absolute_error: 84.7066 - val_loss: 27117.3980 - val_mean_absolute_error: 80.0561
# Epoch 51/1000
#  - 23s - loss: 30699.9460 - mean_absolute_error: 85.9502 - val_loss: 133748.2462 - val_mean_absolute_error: 100.2574
# Epoch 52/1000
#  - 23s - loss: 29970.8913 - mean_absolute_error: 84.3047 - val_loss: 28860.2202 - val_mean_absolute_error: 98.0112
# Epoch 53/1000
#  - 22s - loss: 30198.5376 - mean_absolute_error: 87.4571 - val_loss: 29433.1102 - val_mean_absolute_error: 99.4362
# Epoch 54/1000
#  - 23s - loss: 31780.1255 - mean_absolute_error: 90.6882 - val_loss: 27292.8938 - val_mean_absolute_error: 83.7073
# Epoch 55/1000
#  - 23s - loss: 30639.5257 - mean_absolute_error: 86.6486 - val_loss: 27015.6353 - val_mean_absolute_error: 83.2231
# Epoch 56/1000
#  - 23s - loss: 31078.8117 - mean_absolute_error: 88.8010 - val_loss: 50139072.0062 - val_mean_absolute_error: 391.6257
# Epoch 57/1000
#  - 22s - loss: 30549.6912 - mean_absolute_error: 87.0098 - val_loss: 2146045.1419 - val_mean_absolute_error: 196.9026
# Epoch 58/1000
#  - 23s - loss: 30468.7662 - mean_absolute_error: 86.7039 - val_loss: 27574.4863 - val_mean_absolute_error: 92.2569
# Epoch 59/1000
#  - 23s - loss: 31508.7958 - mean_absolute_error: 90.1737 - val_loss: 26714.5331 - val_mean_absolute_error: 80.3387
# Epoch 60/1000
#  - 23s - loss: 30677.8934 - mean_absolute_error: 87.5196 - val_loss: 26854.5329 - val_mean_absolute_error: 80.5746
# Epoch 61/1000
#  - 23s - loss: 30465.1520 - mean_absolute_error: 87.3931 - val_loss: 26912.9225 - val_mean_absolute_error: 82.0781
# Epoch 62/1000
#  - 23s - loss: 30046.3601 - mean_absolute_error: 84.5343 - val_loss: 26346.0266 - val_mean_absolute_error: 79.6458
# Epoch 63/1000
#  - 23s - loss: 29822.1223 - mean_absolute_error: 84.9419 - val_loss: 26124.0833 - val_mean_absolute_error: 76.7461
# Epoch 64/1000
#  - 22s - loss: 29223.9244 - mean_absolute_error: 82.3918 - val_loss: 26175.1953 - val_mean_absolute_error: 79.3134
# Epoch 65/1000
#  - 23s - loss: 30657.6643 - mean_absolute_error: 85.6947 - val_loss: 27177.0371 - val_mean_absolute_error: 90.0717
# Epoch 66/1000
#  - 23s - loss: 30753.3229 - mean_absolute_error: 88.1944 - val_loss: 26358.5953 - val_mean_absolute_error: 82.0816
# Epoch 67/1000
#  - 23s - loss: 29732.5571 - mean_absolute_error: 85.5635 - val_loss: 189279097.5825 - val_mean_absolute_error: 687.4444
# Epoch 68/1000
#  - 22s - loss: 29001.6491 - mean_absolute_error: 83.1884 - val_loss: 43214.6229 - val_mean_absolute_error: 92.6729
# Epoch 69/1000
#  - 23s - loss: 29598.3553 - mean_absolute_error: 84.6148 - val_loss: 1381386.6175 - val_mean_absolute_error: 137.6838
# Epoch 70/1000
#  - 23s - loss: 29533.1842 - mean_absolute_error: 84.0505 - val_loss: 25518.4413 - val_mean_absolute_error: 74.7275
# Epoch 71/1000
#  - 23s - loss: 28756.5869 - mean_absolute_error: 83.9328 - val_loss: 10267162.0800 - val_mean_absolute_error: 440.7779
# Epoch 72/1000
#  - 22s - loss: 29226.4042 - mean_absolute_error: 83.6804 - val_loss: 885767.4822 - val_mean_absolute_error: 105.6151
# Epoch 73/1000
#  - 23s - loss: 28995.0378 - mean_absolute_error: 85.0560 - val_loss: 73439.7847 - val_mean_absolute_error: 92.8835
# Epoch 74/1000
#  - 23s - loss: 28621.1853 - mean_absolute_error: 83.0233 - val_loss: 76645.6141 - val_mean_absolute_error: 79.9858
# Epoch 75/1000
#  - 23s - loss: 29113.7979 - mean_absolute_error: 84.8934 - val_loss: 25656.6803 - val_mean_absolute_error: 73.9402
# Epoch 76/1000
#  - 23s - loss: 27935.5549 - mean_absolute_error: 80.7646 - val_loss: 25287.8835 - val_mean_absolute_error: 77.3052
# Epoch 77/1000
#  - 23s - loss: 28607.5590 - mean_absolute_error: 81.4372 - val_loss: 25227.1621 - val_mean_absolute_error: 76.6839
# Epoch 78/1000
#  - 23s - loss: 28059.2833 - mean_absolute_error: 81.5288 - val_loss: 24969.1884 - val_mean_absolute_error: 72.6168
# Epoch 79/1000
#  - 22s - loss: 29100.5286 - mean_absolute_error: 84.0700 - val_loss: 615489.0100 - val_mean_absolute_error: 123.9090
# Epoch 80/1000
#  - 23s - loss: 27862.3335 - mean_absolute_error: 81.1567 - val_loss: 25390.2983 - val_mean_absolute_error: 79.9097
# Epoch 81/1000
#  - 23s - loss: 28208.3267 - mean_absolute_error: 82.5818 - val_loss: 2334993.2589 - val_mean_absolute_error: 128.1426
# Epoch 82/1000
#  - 23s - loss: 27911.2986 - mean_absolute_error: 80.6266 - val_loss: 24649.8312 - val_mean_absolute_error: 71.5314
# Epoch 83/1000
#  - 22s - loss: 29426.7791 - mean_absolute_error: 87.8581 - val_loss: 71964.7081 - val_mean_absolute_error: 105.0486
# Epoch 84/1000
#  - 23s - loss: 28889.8693 - mean_absolute_error: 86.5012 - val_loss: 25611.3414 - val_mean_absolute_error: 82.7052
# Epoch 85/1000
#  - 23s - loss: 28305.6131 - mean_absolute_error: 83.4319 - val_loss: 25360.1620 - val_mean_absolute_error: 81.9515
# Epoch 86/1000
#  - 23s - loss: 28045.0554 - mean_absolute_error: 81.1824 - val_loss: 24386.7505 - val_mean_absolute_error: 71.8638
# Epoch 87/1000
#  - 22s - loss: 28298.7196 - mean_absolute_error: 81.6797 - val_loss: 24376.7544 - val_mean_absolute_error: 73.0537
# Epoch 88/1000
#  - 23s - loss: 26913.4973 - mean_absolute_error: 78.2589 - val_loss: 24422.5902 - val_mean_absolute_error: 72.7637
# Epoch 89/1000
#  - 23s - loss: 27817.5215 - mean_absolute_error: 83.7866 - val_loss: 27166.1474 - val_mean_absolute_error: 101.9089
# Epoch 90/1000
#  - 23s - loss: 27479.9113 - mean_absolute_error: 81.9778 - val_loss: 14865888.7310 - val_mean_absolute_error: 254.9794
# Epoch 91/1000
#  - 23s - loss: 27064.2766 - mean_absolute_error: 79.3061 - val_loss: 8199017.0559 - val_mean_absolute_error: 202.5996
# Epoch 92/1000
#  - 23s - loss: 26711.8831 - mean_absolute_error: 78.2750 - val_loss: 27587.0711 - val_mean_absolute_error: 72.6651
# Epoch 93/1000
#  - 23s - loss: 27111.1210 - mean_absolute_error: 80.3187 - val_loss: 24570.4693 - val_mean_absolute_error: 73.4886
# Epoch 94/1000
#  - 22s - loss: 26425.8196 - mean_absolute_error: 77.0792 - val_loss: 54217766.0591 - val_mean_absolute_error: 372.3757
# Epoch 95/1000
#  - 23s - loss: 27662.1488 - mean_absolute_error: 80.5718 - val_loss: 63305710.0866 - val_mean_absolute_error: 394.8021
# Epoch 96/1000
#  - 23s - loss: 26781.3215 - mean_absolute_error: 81.2290 - val_loss: 4082767.8664 - val_mean_absolute_error: 187.2998
# Epoch 97/1000
#  - 23s - loss: 26758.9707 - mean_absolute_error: 78.1496 - val_loss: 53467.3990 - val_mean_absolute_error: 88.8562
# Epoch 98/1000
#  - 22s - loss: 26329.1552 - mean_absolute_error: 77.1778 - val_loss: 63260.2892 - val_mean_absolute_error: 87.6595
# Epoch 99/1000
#  - 23s - loss: 27866.2585 - mean_absolute_error: 81.5446 - val_loss: 24858.4691 - val_mean_absolute_error: 88.3756
# Epoch 100/1000
#  - 23s - loss: 26234.7662 - mean_absolute_error: 77.5682 - val_loss: 926291.6199 - val_mean_absolute_error: 120.7707
# Epoch 101/1000
#  - 23s - loss: 26146.0268 - mean_absolute_error: 78.2457 - val_loss: 57661008.4800 - val_mean_absolute_error: 1762.0119
# Epoch 102/1000
#  - 22s - loss: 28465.8238 - mean_absolute_error: 85.4501 - val_loss: 23725.5327 - val_mean_absolute_error: 75.6798
# Epoch 103/1000
#  - 23s - loss: 26043.4621 - mean_absolute_error: 77.7320 - val_loss: 63547.7566 - val_mean_absolute_error: 90.8707
# Epoch 104/1000
#  - 23s - loss: 26770.2508 - mean_absolute_error: 79.9038 - val_loss: 87128.0298 - val_mean_absolute_error: 105.6515
# Epoch 105/1000
#  - 23s - loss: 27222.0735 - mean_absolute_error: 81.1902 - val_loss: 25605.7086 - val_mean_absolute_error: 93.3933
# Epoch 106/1000
#  - 23s - loss: 26603.5846 - mean_absolute_error: 80.1290 - val_loss: 23060.2174 - val_mean_absolute_error: 69.2634
# Epoch 107/1000
#  - 23s - loss: 26233.9478 - mean_absolute_error: 79.0074 - val_loss: 29146703.5200 - val_mean_absolute_error: 1717.7055
# Epoch 108/1000
#  - 23s - loss: 26196.0990 - mean_absolute_error: 77.9736 - val_loss: 72065.0500 - val_mean_absolute_error: 160.2547
# Epoch 109/1000
#  - 22s - loss: 25333.4380 - mean_absolute_error: 74.6507 - val_loss: 22792.8766 - val_mean_absolute_error: 68.4059
# Epoch 110/1000
#  - 23s - loss: 26606.0620 - mean_absolute_error: 79.9631 - val_loss: 24360.1259 - val_mean_absolute_error: 89.4532
# Epoch 111/1000
#  - 23s - loss: 25465.0175 - mean_absolute_error: 76.6923 - val_loss: 22869.8186 - val_mean_absolute_error: 74.1590
# Epoch 112/1000
#  - 23s - loss: 26696.6673 - mean_absolute_error: 78.3762 - val_loss: 23132.9119 - val_mean_absolute_error: 77.5630
# Epoch 113/1000
#  - 22s - loss: 25091.5108 - mean_absolute_error: 74.9987 - val_loss: 22712.4362 - val_mean_absolute_error: 71.8828
# Epoch 114/1000
#  - 23s - loss: 24789.0333 - mean_absolute_error: 74.9724 - val_loss: 7068811.7034 - val_mean_absolute_error: 205.3696
# Epoch 115/1000
#  - 23s - loss: 25122.5587 - mean_absolute_error: 75.6610 - val_loss: 22892.5109 - val_mean_absolute_error: 76.0935
# Epoch 116/1000
#  - 23s - loss: 25430.0959 - mean_absolute_error: 78.7694 - val_loss: 23012.0211 - val_mean_absolute_error: 75.7921
# Epoch 117/1000
#  - 22s - loss: 25587.5104 - mean_absolute_error: 77.3991 - val_loss: 22616.2466 - val_mean_absolute_error: 73.6875
# Epoch 118/1000
#  - 23s - loss: 25131.1853 - mean_absolute_error: 76.4290 - val_loss: 23446.0666 - val_mean_absolute_error: 70.2619
# Epoch 119/1000
#  - 23s - loss: 25350.9323 - mean_absolute_error: 75.4110 - val_loss: 22237.9734 - val_mean_absolute_error: 70.8157
# Epoch 120/1000
#  - 23s - loss: 25841.9928 - mean_absolute_error: 76.6757 - val_loss: 23285.0011 - val_mean_absolute_error: 84.9162
# Epoch 121/1000
#  - 23s - loss: 25155.6847 - mean_absolute_error: 74.6341 - val_loss: 22029.3060 - val_mean_absolute_error: 68.9974
# Epoch 122/1000
#  - 23s - loss: 24838.0515 - mean_absolute_error: 74.6156 - val_loss: 22000.6978 - val_mean_absolute_error: 67.6984
# Epoch 123/1000
#  - 23s - loss: 24778.0463 - mean_absolute_error: 73.5997 - val_loss: 22519.9366 - val_mean_absolute_error: 77.2817
# Epoch 124/1000
#  - 22s - loss: 24178.6129 - mean_absolute_error: 71.8580 - val_loss: 21989.1812 - val_mean_absolute_error: 70.9515
# Epoch 125/1000
#  - 23s - loss: 25078.9591 - mean_absolute_error: 75.0591 - val_loss: 22038.5904 - val_mean_absolute_error: 70.8408
# Epoch 126/1000
#  - 23s - loss: 24525.9043 - mean_absolute_error: 73.4299 - val_loss: 21941.5120 - val_mean_absolute_error: 71.4669
# Epoch 127/1000
#  - 23s - loss: 24744.2915 - mean_absolute_error: 76.0341 - val_loss: 21791.4955 - val_mean_absolute_error: 69.7897
# Epoch 128/1000
#  - 22s - loss: 24397.2587 - mean_absolute_error: 73.3723 - val_loss: 22659.3480 - val_mean_absolute_error: 82.4465
# Epoch 129/1000
#  - 23s - loss: 25006.1010 - mean_absolute_error: 79.8709 - val_loss: 30691085107435928.0000 - val_mean_absolute_error: 79556200.3200
# Epoch 130/1000
#  - 23s - loss: 24659.9058 - mean_absolute_error: 79.4214 - val_loss: 21317382512.6400 - val_mean_absolute_error: 36597.9682
# Epoch 131/1000
#  - 23s - loss: 24560.2023 - mean_absolute_error: 75.6193 - val_loss: 216809.8728 - val_mean_absolute_error: 108.8104
# Epoch 132/1000
#  - 22s - loss: 25751.3791 - mean_absolute_error: 79.3981 - val_loss: 3991160.1347 - val_mean_absolute_error: 259.5297
# Epoch 133/1000
#  - 23s - loss: 24046.3807 - mean_absolute_error: 74.1920 - val_loss: 23365.9634 - val_mean_absolute_error: 79.3205
# Epoch 134/1000
#  - 23s - loss: 24537.1777 - mean_absolute_error: 74.0452 - val_loss: 21210.0684 - val_mean_absolute_error: 65.8975
# Epoch 135/1000
#  - 23s - loss: 23465.9451 - mean_absolute_error: 72.3064 - val_loss: 21281.4646 - val_mean_absolute_error: 67.9522
# Epoch 136/1000
#  - 23s - loss: 23893.6309 - mean_absolute_error: 73.1544 - val_loss: 21314.0098 - val_mean_absolute_error: 71.6343
# Epoch 137/1000
#  - 23s - loss: 23497.3832 - mean_absolute_error: 73.5355 - val_loss: 25102.8788 - val_mean_absolute_error: 72.6335
# Epoch 138/1000
#  - 23s - loss: 24003.6673 - mean_absolute_error: 72.2707 - val_loss: 23962.2852 - val_mean_absolute_error: 70.9258
# Epoch 139/1000
#  - 22s - loss: 23231.5065 - mean_absolute_error: 71.9759 - val_loss: 21588.4866 - val_mean_absolute_error: 69.6732
# Epoch 140/1000
#  - 23s - loss: 24343.5196 - mean_absolute_error: 74.7039 - val_loss: 22682.9927 - val_mean_absolute_error: 89.2944
# Epoch 141/1000
#  - 23s - loss: 23587.4227 - mean_absolute_error: 73.1202 - val_loss: 21641.2749 - val_mean_absolute_error: 68.0717
# Epoch 142/1000
#  - 23s - loss: 23839.0067 - mean_absolute_error: 74.0812 - val_loss: 21133.3977 - val_mean_absolute_error: 69.1535
# Epoch 143/1000
#  - 22s - loss: 22868.2024 - mean_absolute_error: 74.2631 - val_loss: 48341459933.3866 - val_mean_absolute_error: 9490.2851
# Epoch 144/1000
#  - 23s - loss: 23323.6909 - mean_absolute_error: 72.8610 - val_loss: 22590.9585 - val_mean_absolute_error: 75.8854
# Epoch 145/1000
#  - 23s - loss: 23568.9441 - mean_absolute_error: 74.3933 - val_loss: 26089.9666 - val_mean_absolute_error: 96.4823
# Epoch 146/1000
#  - 23s - loss: 22867.8094 - mean_absolute_error: 70.8206 - val_loss: 20783.8819 - val_mean_absolute_error: 71.0972
# Epoch 147/1000
#  - 22s - loss: 23106.0313 - mean_absolute_error: 70.9678 - val_loss: 20618.6599 - val_mean_absolute_error: 71.5315
# Epoch 148/1000
#  - 23s - loss: 22719.0005 - mean_absolute_error: 70.7672 - val_loss: 25781.7059 - val_mean_absolute_error: 76.1392
# Epoch 149/1000
#  - 23s - loss: 23316.0547 - mean_absolute_error: 70.7741 - val_loss: 20797.3429 - val_mean_absolute_error: 73.8804
# Epoch 150/1000
#  - 23s - loss: 22797.9131 - mean_absolute_error: 71.0184 - val_loss: 20255.9617 - val_mean_absolute_error: 64.4908
# Epoch 151/1000
#  - 23s - loss: 22483.4157 - mean_absolute_error: 70.3989 - val_loss: 20267.8831 - val_mean_absolute_error: 65.8467
# Epoch 152/1000
#  - 23s - loss: 22274.8144 - mean_absolute_error: 68.4972 - val_loss: 20604.1651 - val_mean_absolute_error: 72.6132
# Epoch 153/1000
#  - 23s - loss: 22724.6356 - mean_absolute_error: 69.7012 - val_loss: 20192.4228 - val_mean_absolute_error: 68.0573
# Epoch 154/1000
#  - 22s - loss: 22754.7493 - mean_absolute_error: 70.7926 - val_loss: 4704158246502.4004 - val_mean_absolute_error: 660303.6425
# Epoch 155/1000
#  - 23s - loss: 21916.7526 - mean_absolute_error: 68.7088 - val_loss: 31108454318.0800 - val_mean_absolute_error: 47461.7686
# Epoch 156/1000
#  - 23s - loss: 22658.7102 - mean_absolute_error: 72.4798 - val_loss: 28908.7384 - val_mean_absolute_error: 85.7424
# Epoch 157/1000
#  - 23s - loss: 22390.6506 - mean_absolute_error: 70.8887 - val_loss: 20211.2812 - val_mean_absolute_error: 65.9974
# Epoch 158/1000
#  - 22s - loss: 22481.3034 - mean_absolute_error: 72.3400 - val_loss: 20197.1002 - val_mean_absolute_error: 74.7574
# Epoch 159/1000
#  - 23s - loss: 23335.6981 - mean_absolute_error: 78.6376 - val_loss: 23441.0656 - val_mean_absolute_error: 93.8105
# Epoch 160/1000
#  - 23s - loss: 22659.9166 - mean_absolute_error: 74.5729 - val_loss: 20099.3516 - val_mean_absolute_error: 71.1931
# Epoch 161/1000
#  - 23s - loss: 22451.2462 - mean_absolute_error: 74.0134 - val_loss: 19673.1169 - val_mean_absolute_error: 69.6076
# Epoch 162/1000
#  - 22s - loss: 22944.4632 - mean_absolute_error: 76.2812 - val_loss: 23532.3724 - val_mean_absolute_error: 106.6899
# Epoch 163/1000
#  - 23s - loss: 22590.1312 - mean_absolute_error: 74.5110 - val_loss: 20150.6366 - val_mean_absolute_error: 75.2205
# Epoch 164/1000
#  - 23s - loss: 22850.6046 - mean_absolute_error: 75.4076 - val_loss: 20778.6795 - val_mean_absolute_error: 66.8385
# Epoch 165/1000
#  - 23s - loss: 21604.2820 - mean_absolute_error: 70.0342 - val_loss: 19576.9114 - val_mean_absolute_error: 67.6255
# Epoch 166/1000
#  - 23s - loss: 22110.9591 - mean_absolute_error: 71.3683 - val_loss: 19372.5753 - val_mean_absolute_error: 67.6361
# Epoch 167/1000
#  - 23s - loss: 21952.9881 - mean_absolute_error: 71.7970 - val_loss: 19909.5588 - val_mean_absolute_error: 76.3631
# Epoch 168/1000
#  - 23s - loss: 21821.2514 - mean_absolute_error: 70.3441 - val_loss: 19102.1416 - val_mean_absolute_error: 65.1290
# Epoch 169/1000
#  - 22s - loss: 22370.6137 - mean_absolute_error: 72.1263 - val_loss: 19055.3749 - val_mean_absolute_error: 65.0295
# Epoch 170/1000
#  - 23s - loss: 21749.1389 - mean_absolute_error: 71.3944 - val_loss: 27586.5648 - val_mean_absolute_error: 98.0321
# Epoch 171/1000
#  - 23s - loss: 21680.3682 - mean_absolute_error: 72.4545 - val_loss: 19389.7526 - val_mean_absolute_error: 68.5494
# Epoch 172/1000
#  - 23s - loss: 21571.8194 - mean_absolute_error: 69.1798 - val_loss: 18801.7169 - val_mean_absolute_error: 62.4574
# Epoch 173/1000
#  - 22s - loss: 21217.1861 - mean_absolute_error: 67.7849 - val_loss: 20653.1265 - val_mean_absolute_error: 65.8204
# Epoch 174/1000
#  - 23s - loss: 20698.7533 - mean_absolute_error: 67.5922 - val_loss: 23621.9234 - val_mean_absolute_error: 72.5212
# Epoch 175/1000
#  - 23s - loss: 21487.7649 - mean_absolute_error: 68.7941 - val_loss: 19884.5291 - val_mean_absolute_error: 78.8153
# Epoch 176/1000
#  - 23s - loss: 20960.5519 - mean_absolute_error: 67.7861 - val_loss: 18985.3877 - val_mean_absolute_error: 65.9642
# Epoch 177/1000
#  - 22s - loss: 21153.0359 - mean_absolute_error: 69.1760 - val_loss: 18552.5962 - val_mean_absolute_error: 61.6016
# Epoch 178/1000
#  - 23s - loss: 20445.5735 - mean_absolute_error: 67.0640 - val_loss: 25787.1498 - val_mean_absolute_error: 74.7577
# Epoch 179/1000
#  - 23s - loss: 21093.3979 - mean_absolute_error: 67.7938 - val_loss: 18549.8534 - val_mean_absolute_error: 64.6694
# Epoch 180/1000
#  - 23s - loss: 20263.1301 - mean_absolute_error: 66.3690 - val_loss: 18571.2214 - val_mean_absolute_error: 67.0340
# Epoch 181/1000
#  - 23s - loss: 20363.0794 - mean_absolute_error: 67.3067 - val_loss: 18248.9702 - val_mean_absolute_error: 61.6452
# Epoch 182/1000
#  - 23s - loss: 21522.3600 - mean_absolute_error: 74.2287 - val_loss: 20087.5628 - val_mean_absolute_error: 87.2799
# Epoch 183/1000
#  - 23s - loss: 20982.2592 - mean_absolute_error: 73.3243 - val_loss: 18975.2080 - val_mean_absolute_error: 74.3475
# Epoch 184/1000
#  - 22s - loss: 20708.2327 - mean_absolute_error: 68.9320 - val_loss: 19169.2694 - val_mean_absolute_error: 77.7435
# Epoch 185/1000
#  - 23s - loss: 20083.9880 - mean_absolute_error: 67.3436 - val_loss: 18847.8104 - val_mean_absolute_error: 64.5771
# Epoch 186/1000
#  - 23s - loss: 21245.5895 - mean_absolute_error: 69.5960 - val_loss: 18979.6795 - val_mean_absolute_error: 75.1139
# Epoch 187/1000
#  - 23s - loss: 21133.9830 - mean_absolute_error: 73.1502 - val_loss: 18798.7027 - val_mean_absolute_error: 70.6798
# Epoch 188/1000
#  - 22s - loss: 20393.3407 - mean_absolute_error: 68.8881 - val_loss: 18327.8759 - val_mean_absolute_error: 66.4840
# Epoch 189/1000
#  - 23s - loss: 20156.2817 - mean_absolute_error: 66.0978 - val_loss: 17810.3881 - val_mean_absolute_error: 60.3440
# Epoch 190/1000
#  - 23s - loss: 19793.7355 - mean_absolute_error: 65.2926 - val_loss: 17996.8350 - val_mean_absolute_error: 64.2793
# Epoch 191/1000
#  - 23s - loss: 19643.0033 - mean_absolute_error: 67.2483 - val_loss: 22824.0734 - val_mean_absolute_error: 89.7063
# Epoch 192/1000
#  - 22s - loss: 19852.2174 - mean_absolute_error: 65.5939 - val_loss: 18229.5920 - val_mean_absolute_error: 63.5776
# Epoch 193/1000
#  - 23s - loss: 19698.7809 - mean_absolute_error: 65.2332 - val_loss: 18481.3317 - val_mean_absolute_error: 63.6929
# Epoch 194/1000
#  - 23s - loss: 19724.0715 - mean_absolute_error: 64.6338 - val_loss: 17873.9125 - val_mean_absolute_error: 63.6077
# Epoch 195/1000
#  - 23s - loss: 20038.0228 - mean_absolute_error: 65.6912 - val_loss: 17991.6042 - val_mean_absolute_error: 65.6911
# Epoch 196/1000
#  - 23s - loss: 19550.2782 - mean_absolute_error: 66.0041 - val_loss: 17728.4898 - val_mean_absolute_error: 65.2701
# Epoch 197/1000
#  - 23s - loss: 20762.9415 - mean_absolute_error: 71.2822 - val_loss: 18401.9417 - val_mean_absolute_error: 76.7026
# Epoch 198/1000
#  - 23s - loss: 19842.2358 - mean_absolute_error: 68.6784 - val_loss: 17510.8194 - val_mean_absolute_error: 62.9621
# Epoch 199/1000
#  - 22s - loss: 20535.2054 - mean_absolute_error: 69.4922 - val_loss: 19023.7855 - val_mean_absolute_error: 79.5195
# Epoch 200/1000
#  - 23s - loss: 19559.2380 - mean_absolute_error: 67.2956 - val_loss: 23007.8444 - val_mean_absolute_error: 75.6167
# Epoch 201/1000
#  - 23s - loss: 19464.5450 - mean_absolute_error: 65.9488 - val_loss: 17460.7402 - val_mean_absolute_error: 65.3429
# Epoch 202/1000
#  - 23s - loss: 19524.3627 - mean_absolute_error: 64.7840 - val_loss: 17171.8848 - val_mean_absolute_error: 61.5762
# Epoch 203/1000
#  - 22s - loss: 19143.1948 - mean_absolute_error: 65.0063 - val_loss: 17683.1916 - val_mean_absolute_error: 67.7989
# Epoch 204/1000
#  - 23s - loss: 19658.3196 - mean_absolute_error: 70.5068 - val_loss: 17984.4578 - val_mean_absolute_error: 75.8233
# Epoch 205/1000
#  - 23s - loss: 18642.8172 - mean_absolute_error: 64.6910 - val_loss: 18853.8908 - val_mean_absolute_error: 64.1813
# Epoch 206/1000
#  - 23s - loss: 18712.9593 - mean_absolute_error: 63.8616 - val_loss: 16848.5260 - val_mean_absolute_error: 58.2029
# Epoch 207/1000
#  - 22s - loss: 19105.7527 - mean_absolute_error: 64.0170 - val_loss: 17166.0780 - val_mean_absolute_error: 65.7244
# Epoch 208/1000
#  - 23s - loss: 19948.9011 - mean_absolute_error: 69.1171 - val_loss: 19004.9850 - val_mean_absolute_error: 77.6033
# Epoch 209/1000
#  - 23s - loss: 19150.1341 - mean_absolute_error: 71.6149 - val_loss: 17773.9250 - val_mean_absolute_error: 72.8360
# Epoch 210/1000
#  - 23s - loss: 19323.5958 - mean_absolute_error: 69.9628 - val_loss: 27205.1080 - val_mean_absolute_error: 113.0935
# Epoch 211/1000
#  - 23s - loss: 18958.9829 - mean_absolute_error: 68.0193 - val_loss: 17206.9691 - val_mean_absolute_error: 66.5964
# Epoch 212/1000
#  - 23s - loss: 19338.5329 - mean_absolute_error: 70.0747 - val_loss: 17278.3388 - val_mean_absolute_error: 63.5814
# Epoch 213/1000
#  - 23s - loss: 18455.2145 - mean_absolute_error: 67.6934 - val_loss: 18884.1152 - val_mean_absolute_error: 76.0973
# Epoch 214/1000
#  - 22s - loss: 19024.2962 - mean_absolute_error: 68.8923 - val_loss: 24720.6509 - val_mean_absolute_error: 83.9888
# Epoch 215/1000
#  - 23s - loss: 18028.3919 - mean_absolute_error: 64.7906 - val_loss: 17006.4227 - val_mean_absolute_error: 64.4310
# Epoch 216/1000
#  - 23s - loss: 18902.7057 - mean_absolute_error: 66.1703 - val_loss: 17813.3406 - val_mean_absolute_error: 76.9207
# Epoch 217/1000
#  - 23s - loss: 18116.0637 - mean_absolute_error: 64.4924 - val_loss: 16471.7381 - val_mean_absolute_error: 59.9567
# Epoch 218/1000
#  - 22s - loss: 18321.8330 - mean_absolute_error: 64.2442 - val_loss: 16638.5375 - val_mean_absolute_error: 64.4150
# Epoch 219/1000
#  - 23s - loss: 18099.1499 - mean_absolute_error: 63.1323 - val_loss: 16694.5534 - val_mean_absolute_error: 61.4696
# Epoch 220/1000
#  - 23s - loss: 18666.9967 - mean_absolute_error: 66.6224 - val_loss: 16393.3193 - val_mean_absolute_error: 64.0075
# Epoch 221/1000
#  - 23s - loss: 19049.4195 - mean_absolute_error: 71.7151 - val_loss: 22291.8222 - val_mean_absolute_error: 73.4239
# Epoch 222/1000
#  - 22s - loss: 18216.8326 - mean_absolute_error: 65.2809 - val_loss: 18803.1171 - val_mean_absolute_error: 62.7333
# Epoch 223/1000
#  - 23s - loss: 17814.6845 - mean_absolute_error: 63.8454 - val_loss: 21039.0219 - val_mean_absolute_error: 68.5667
# Epoch 224/1000
#  - 23s - loss: 18115.6818 - mean_absolute_error: 65.0625 - val_loss: 17477.7551 - val_mean_absolute_error: 60.1069
# Epoch 225/1000
#  - 23s - loss: 18632.0388 - mean_absolute_error: 67.7609 - val_loss: 16497.4080 - val_mean_absolute_error: 67.7325
# Epoch 226/1000
#  - 23s - loss: 18111.7939 - mean_absolute_error: 67.0891 - val_loss: 16401.3291 - val_mean_absolute_error: 63.3200
# Epoch 227/1000
#  - 23s - loss: 17817.6857 - mean_absolute_error: 63.7276 - val_loss: 16242.8882 - val_mean_absolute_error: 59.4122
# Epoch 228/1000
#  - 23s - loss: 18036.9576 - mean_absolute_error: 63.5011 - val_loss: 16236.8165 - val_mean_absolute_error: 67.6601
# Epoch 229/1000
#  - 22s - loss: 17902.5644 - mean_absolute_error: 62.4724 - val_loss: 15696.1625 - val_mean_absolute_error: 60.6904
# Epoch 230/1000
#  - 23s - loss: 17015.7548 - mean_absolute_error: 60.6458 - val_loss: 15740.6934 - val_mean_absolute_error: 60.2303
# Epoch 231/1000
#  - 23s - loss: 17894.3456 - mean_absolute_error: 62.1659 - val_loss: 15792.9655 - val_mean_absolute_error: 58.8943
# Epoch 232/1000
#  - 23s - loss: 17262.2682 - mean_absolute_error: 61.9864 - val_loss: 15905.5741 - val_mean_absolute_error: 64.3477
# Epoch 233/1000
#  - 22s - loss: 17410.4809 - mean_absolute_error: 61.6434 - val_loss: 19256.5041 - val_mean_absolute_error: 65.5255
# Epoch 234/1000
#  - 23s - loss: 17151.0023 - mean_absolute_error: 61.0780 - val_loss: 16417.4905 - val_mean_absolute_error: 58.9567
# Epoch 235/1000
#  - 23s - loss: 17228.2899 - mean_absolute_error: 60.4832 - val_loss: 18406.9591 - val_mean_absolute_error: 61.0314
# Epoch 236/1000
#  - 23s - loss: 17416.1279 - mean_absolute_error: 61.6047 - val_loss: 128367.2189 - val_mean_absolute_error: 80.8799
# Epoch 237/1000
#  - 22s - loss: 17123.6521 - mean_absolute_error: 61.7984 - val_loss: 15381.7132 - val_mean_absolute_error: 58.6036
# Epoch 238/1000
#  - 23s - loss: 16964.3824 - mean_absolute_error: 60.7721 - val_loss: 15610.9330 - val_mean_absolute_error: 61.3000
# Epoch 239/1000
#  - 23s - loss: 16962.4651 - mean_absolute_error: 60.4127 - val_loss: 15224.2243 - val_mean_absolute_error: 57.2610
# Epoch 240/1000
#  - 23s - loss: 17019.5832 - mean_absolute_error: 61.0957 - val_loss: 20089.4623 - val_mean_absolute_error: 68.6785
# Epoch 241/1000
#  - 23s - loss: 16333.6175 - mean_absolute_error: 59.1289 - val_loss: 15337.2959 - val_mean_absolute_error: 62.2092
# Epoch 242/1000
#  - 23s - loss: 16493.6888 - mean_absolute_error: 59.0804 - val_loss: 16281.4569 - val_mean_absolute_error: 72.3806
# Epoch 243/1000
#  - 23s - loss: 16685.9027 - mean_absolute_error: 59.8093 - val_loss: 14984.0112 - val_mean_absolute_error: 58.0061
# Epoch 244/1000
#  - 22s - loss: 16138.5686 - mean_absolute_error: 60.0658 - val_loss: 21517.9411 - val_mean_absolute_error: 84.6082
# Epoch 245/1000
#  - 23s - loss: 16762.9341 - mean_absolute_error: 62.1082 - val_loss: 14971.4919 - val_mean_absolute_error: 56.8566
# Epoch 246/1000
#  - 23s - loss: 16221.9561 - mean_absolute_error: 59.4254 - val_loss: 19355.3380 - val_mean_absolute_error: 71.5723
# Epoch 247/1000
#  - 23s - loss: 16856.0857 - mean_absolute_error: 64.6479 - val_loss: 15392.9672 - val_mean_absolute_error: 66.6494
# Epoch 248/1000
#  - 22s - loss: 16311.5735 - mean_absolute_error: 60.8745 - val_loss: 14830.2125 - val_mean_absolute_error: 59.5372
# Epoch 249/1000
#  - 23s - loss: 16416.9991 - mean_absolute_error: 59.6514 - val_loss: 14579.4256 - val_mean_absolute_error: 55.8721
# Epoch 250/1000
#  - 23s - loss: 15969.0199 - mean_absolute_error: 58.4870 - val_loss: 14577.7673 - val_mean_absolute_error: 56.0239
# Epoch 251/1000
#  - 23s - loss: 16169.6608 - mean_absolute_error: 58.2604 - val_loss: 14880.9352 - val_mean_absolute_error: 61.4028
# Epoch 252/1000
#  - 22s - loss: 16499.0810 - mean_absolute_error: 61.8247 - val_loss: 16796.9174 - val_mean_absolute_error: 66.1693
# Epoch 253/1000
#  - 23s - loss: 16254.8386 - mean_absolute_error: 60.9166 - val_loss: 15194.9624 - val_mean_absolute_error: 61.7037
# Epoch 254/1000
#  - 23s - loss: 15898.6855 - mean_absolute_error: 62.7214 - val_loss: 15943.8079 - val_mean_absolute_error: 70.1330
# Epoch 255/1000
#  - 23s - loss: 15764.5848 - mean_absolute_error: 60.9362 - val_loss: 17886.0019 - val_mean_absolute_error: 79.3061
# Epoch 256/1000
#  - 23s - loss: 16456.8804 - mean_absolute_error: 60.7676 - val_loss: 14316.3894 - val_mean_absolute_error: 57.7756
# Epoch 257/1000
#  - 23s - loss: 16204.3746 - mean_absolute_error: 59.4436 - val_loss: 15638.8278 - val_mean_absolute_error: 71.9806
# Epoch 258/1000
#  - 23s - loss: 16119.1311 - mean_absolute_error: 61.8567 - val_loss: 18290.7842 - val_mean_absolute_error: 93.1959
# Epoch 259/1000
#  - 22s - loss: 15729.9322 - mean_absolute_error: 62.7315 - val_loss: 17665.4409 - val_mean_absolute_error: 79.5389
# Epoch 260/1000
#  - 23s - loss: 15572.5926 - mean_absolute_error: 59.4769 - val_loss: 14504.3337 - val_mean_absolute_error: 55.3782
# Epoch 261/1000
#  - 23s - loss: 15763.6256 - mean_absolute_error: 59.5206 - val_loss: 14125.9293 - val_mean_absolute_error: 57.7638
# Epoch 262/1000
#  - 23s - loss: 16117.9065 - mean_absolute_error: 60.2445 - val_loss: 14295.2389 - val_mean_absolute_error: 63.6713
# Epoch 263/1000
#  - 22s - loss: 15530.6755 - mean_absolute_error: 61.5454 - val_loss: 14795.1200 - val_mean_absolute_error: 67.0039
# Epoch 264/1000
#  - 23s - loss: 15642.4713 - mean_absolute_error: 61.6832 - val_loss: 14262.0402 - val_mean_absolute_error: 60.5722
# Epoch 265/1000
#  - 23s - loss: 15457.8490 - mean_absolute_error: 59.9476 - val_loss: 13833.2425 - val_mean_absolute_error: 54.6639
# Epoch 266/1000
#  - 23s - loss: 15178.3540 - mean_absolute_error: 57.4994 - val_loss: 14717.7539 - val_mean_absolute_error: 61.2661
# Epoch 267/1000
#  - 22s - loss: 15082.2951 - mean_absolute_error: 56.9492 - val_loss: 14435.4431 - val_mean_absolute_error: 59.1163
# Epoch 268/1000
#  - 23s - loss: 15367.5618 - mean_absolute_error: 58.3194 - val_loss: 14376.6814 - val_mean_absolute_error: 65.7390
# Epoch 269/1000
#  - 23s - loss: 14797.9035 - mean_absolute_error: 56.7633 - val_loss: 15880.2772 - val_mean_absolute_error: 61.9725
# Epoch 270/1000
#  - 23s - loss: 15377.6638 - mean_absolute_error: 57.8352 - val_loss: 15275.5746 - val_mean_absolute_error: 66.5435
# Epoch 271/1000
#  - 23s - loss: 14829.0478 - mean_absolute_error: 56.3690 - val_loss: 13844.2214 - val_mean_absolute_error: 56.8447
# Epoch 272/1000
#  - 23s - loss: 14926.2411 - mean_absolute_error: 59.4066 - val_loss: 19368.0575 - val_mean_absolute_error: 68.4092
# Epoch 273/1000
#  - 23s - loss: 14780.1079 - mean_absolute_error: 56.6894 - val_loss: 15251.3532 - val_mean_absolute_error: 59.7334
# Epoch 274/1000
#  - 22s - loss: 14778.9920 - mean_absolute_error: 56.8371 - val_loss: 14561.2964 - val_mean_absolute_error: 70.6199
# Epoch 275/1000
#  - 23s - loss: 15157.2678 - mean_absolute_error: 60.6275 - val_loss: 18767.4341 - val_mean_absolute_error: 93.9705
# Epoch 276/1000
#  - 23s - loss: 14815.1364 - mean_absolute_error: 57.9333 - val_loss: 13800.1133 - val_mean_absolute_error: 60.5575
# Epoch 277/1000
#  - 23s - loss: 14569.5357 - mean_absolute_error: 59.3826 - val_loss: 14096.3638 - val_mean_absolute_error: 64.8363
# Epoch 278/1000
#  - 22s - loss: 15143.3840 - mean_absolute_error: 60.0017 - val_loss: 14135.1686 - val_mean_absolute_error: 56.1655
# Epoch 279/1000
#  - 23s - loss: 14516.8160 - mean_absolute_error: 58.3434 - val_loss: 13198.2037 - val_mean_absolute_error: 55.0076
# Epoch 280/1000
#  - 23s - loss: 14426.5856 - mean_absolute_error: 56.2683 - val_loss: 13240.2455 - val_mean_absolute_error: 56.0378
# Epoch 281/1000
#  - 23s - loss: 14424.5856 - mean_absolute_error: 56.4960 - val_loss: 13488.9809 - val_mean_absolute_error: 61.6182
# Epoch 282/1000
#  - 22s - loss: 13958.1588 - mean_absolute_error: 54.2122 - val_loss: 13151.6406 - val_mean_absolute_error: 54.6452
# Epoch 283/1000
#  - 23s - loss: 13942.5380 - mean_absolute_error: 54.8044 - val_loss: 13615.2469 - val_mean_absolute_error: 56.3132
# Epoch 284/1000
#  - 23s - loss: 14374.6342 - mean_absolute_error: 58.2890 - val_loss: 22997.1037 - val_mean_absolute_error: 70.3244
# Epoch 285/1000
#  - 23s - loss: 14273.6007 - mean_absolute_error: 55.7723 - val_loss: 13171.8595 - val_mean_absolute_error: 59.1105
# Epoch 286/1000
#  - 23s - loss: 14499.2140 - mean_absolute_error: 57.0058 - val_loss: 16638.5035 - val_mean_absolute_error: 65.4475
# Epoch 287/1000
#  - 23s - loss: 14037.9807 - mean_absolute_error: 54.6975 - val_loss: 12931.3114 - val_mean_absolute_error: 56.5076
# Epoch 288/1000
#  - 23s - loss: 14077.3285 - mean_absolute_error: 56.2128 - val_loss: 13219.9042 - val_mean_absolute_error: 59.0032
# Epoch 289/1000
#  - 22s - loss: 14051.9319 - mean_absolute_error: 55.7635 - val_loss: 17678.5698 - val_mean_absolute_error: 65.6999
# Epoch 290/1000
#  - 23s - loss: 13924.3180 - mean_absolute_error: 56.1360 - val_loss: 12636.4907 - val_mean_absolute_error: 53.8235
# Epoch 291/1000
#  - 23s - loss: 13816.0819 - mean_absolute_error: 54.2341 - val_loss: 19494.9527 - val_mean_absolute_error: 62.3529
# Epoch 292/1000
#  - 23s - loss: 13835.3801 - mean_absolute_error: 60.7853 - val_loss: 13605.9621 - val_mean_absolute_error: 65.8801
# Epoch 293/1000
#  - 22s - loss: 13717.7590 - mean_absolute_error: 56.4247 - val_loss: 12475.5829 - val_mean_absolute_error: 51.8496
# Epoch 294/1000
#  - 23s - loss: 13817.8870 - mean_absolute_error: 54.0856 - val_loss: 12421.7683 - val_mean_absolute_error: 51.0016
# Epoch 295/1000
#  - 23s - loss: 13472.6896 - mean_absolute_error: 54.2823 - val_loss: 15231.5480 - val_mean_absolute_error: 61.4579
# Epoch 296/1000
#  - 23s - loss: 13635.1132 - mean_absolute_error: 55.2677 - val_loss: 13623.5352 - val_mean_absolute_error: 70.2782
# Epoch 297/1000
#  - 22s - loss: 13994.2882 - mean_absolute_error: 55.3536 - val_loss: 12844.0807 - val_mean_absolute_error: 61.4479
# Epoch 298/1000
#  - 23s - loss: 13484.5195 - mean_absolute_error: 56.2406 - val_loss: 12463.2798 - val_mean_absolute_error: 54.9816
# Epoch 299/1000
#  - 23s - loss: 13334.1412 - mean_absolute_error: 54.6013 - val_loss: 12327.5586 - val_mean_absolute_error: 52.1787
# Epoch 300/1000
#  - 23s - loss: 13661.1801 - mean_absolute_error: 55.0353 - val_loss: 12505.5224 - val_mean_absolute_error: 59.0070
# Epoch 301/1000
#  - 23s - loss: 13666.7309 - mean_absolute_error: 55.3378 - val_loss: 13196.6798 - val_mean_absolute_error: 68.7786
# Epoch 302/1000
#  - 23s - loss: 13538.9826 - mean_absolute_error: 56.1274 - val_loss: 12187.7976 - val_mean_absolute_error: 55.6491
# Epoch 303/1000
#  - 23s - loss: 13016.5434 - mean_absolute_error: 54.7792 - val_loss: 12181.3350 - val_mean_absolute_error: 54.6621
# Epoch 304/1000
#  - 22s - loss: 13351.1761 - mean_absolute_error: 54.1340 - val_loss: 12289.6284 - val_mean_absolute_error: 57.6081
# Epoch 305/1000
#  - 23s - loss: 13500.4713 - mean_absolute_error: 56.1642 - val_loss: 12164.4741 - val_mean_absolute_error: 57.8340
# Epoch 306/1000
#  - 23s - loss: 13680.5555 - mean_absolute_error: 57.1884 - val_loss: 11854.9307 - val_mean_absolute_error: 51.1943
# Epoch 307/1000
#  - 23s - loss: 12974.9064 - mean_absolute_error: 53.1521 - val_loss: 11812.5591 - val_mean_absolute_error: 50.4943
# Epoch 308/1000
#  - 22s - loss: 12834.6331 - mean_absolute_error: 53.6872 - val_loss: 12720.9155 - val_mean_absolute_error: 54.3586
# Epoch 309/1000
#  - 23s - loss: 13492.8944 - mean_absolute_error: 56.9810 - val_loss: 11821.2036 - val_mean_absolute_error: 53.6075
# Epoch 310/1000
#  - 23s - loss: 12931.7527 - mean_absolute_error: 60.8026 - val_loss: 13475.6432 - val_mean_absolute_error: 67.4129
# Epoch 311/1000
#  - 23s - loss: 12804.3940 - mean_absolute_error: 53.2005 - val_loss: 11864.4355 - val_mean_absolute_error: 54.2221
# Epoch 312/1000
#  - 22s - loss: 13150.7771 - mean_absolute_error: 54.0673 - val_loss: 12076.6744 - val_mean_absolute_error: 59.9516
# Epoch 313/1000
#  - 23s - loss: 12558.0500 - mean_absolute_error: 52.1396 - val_loss: 11503.5741 - val_mean_absolute_error: 49.6829
# Epoch 314/1000
#  - 23s - loss: 12468.4735 - mean_absolute_error: 51.9803 - val_loss: 17291.2266 - val_mean_absolute_error: 66.3928
# Epoch 315/1000
#  - 22s - loss: 12787.1769 - mean_absolute_error: 54.3692 - val_loss: 11418.5563 - val_mean_absolute_error: 49.8455
# Epoch 316/1000
#  - 23s - loss: 12516.6894 - mean_absolute_error: 52.6146 - val_loss: 11614.7887 - val_mean_absolute_error: 52.9942
# Epoch 317/1000
#  - 23s - loss: 12555.9331 - mean_absolute_error: 51.9700 - val_loss: 11298.7067 - val_mean_absolute_error: 49.3898
# Epoch 318/1000
#  - 23s - loss: 12136.9147 - mean_absolute_error: 50.8596 - val_loss: 11331.2546 - val_mean_absolute_error: 50.9695
# Epoch 319/1000
#  - 22s - loss: 12456.3695 - mean_absolute_error: 52.8212 - val_loss: 26813.2016 - val_mean_absolute_error: 83.8683
# Epoch 320/1000
#  - 23s - loss: 12742.6630 - mean_absolute_error: 52.6190 - val_loss: 12630.6489 - val_mean_absolute_error: 62.6320
# Epoch 321/1000
#  - 23s - loss: 12433.1396 - mean_absolute_error: 55.5173 - val_loss: 11744.5931 - val_mean_absolute_error: 57.5623
# Epoch 322/1000
#  - 23s - loss: 12154.1169 - mean_absolute_error: 51.8347 - val_loss: 13070.3498 - val_mean_absolute_error: 57.2233
# Epoch 323/1000
#  - 22s - loss: 11737.9904 - mean_absolute_error: 50.4398 - val_loss: 11012.0818 - val_mean_absolute_error: 49.2705
# Epoch 324/1000
#  - 23s - loss: 12517.7472 - mean_absolute_error: 52.8372 - val_loss: 11534.8942 - val_mean_absolute_error: 58.2674
# Epoch 325/1000
#  - 23s - loss: 12043.9546 - mean_absolute_error: 52.9697 - val_loss: 13595.5209 - val_mean_absolute_error: 70.2949
# Epoch 326/1000
#  - 23s - loss: 11865.7802 - mean_absolute_error: 50.0926 - val_loss: 10902.6228 - val_mean_absolute_error: 48.4541
# Epoch 327/1000
#  - 22s - loss: 12086.2112 - mean_absolute_error: 50.3150 - val_loss: 11142.2009 - val_mean_absolute_error: 53.5884
# Epoch 328/1000
#  - 23s - loss: 12478.2937 - mean_absolute_error: 53.7009 - val_loss: 11600.8379 - val_mean_absolute_error: 61.2160
# Epoch 329/1000
#  - 23s - loss: 11864.3773 - mean_absolute_error: 50.8333 - val_loss: 10765.8805 - val_mean_absolute_error: 48.1038
# Epoch 330/1000
#  - 22s - loss: 11781.7375 - mean_absolute_error: 50.7741 - val_loss: 10795.9336 - val_mean_absolute_error: 47.9866
# Epoch 331/1000
#  - 23s - loss: 11608.7661 - mean_absolute_error: 51.1461 - val_loss: 11125.4632 - val_mean_absolute_error: 53.6506
# Epoch 332/1000
#  - 23s - loss: 11860.9779 - mean_absolute_error: 52.6981 - val_loss: 10875.1333 - val_mean_absolute_error: 51.5775
# Epoch 333/1000
#  - 23s - loss: 12021.0006 - mean_absolute_error: 56.4757 - val_loss: 5126563.9400 - val_mean_absolute_error: 677.5651
# Epoch 334/1000
#  - 22s - loss: 11810.2694 - mean_absolute_error: 54.4830 - val_loss: 11941.9175 - val_mean_absolute_error: 63.8372
# Epoch 335/1000
#  - 23s - loss: 11983.1512 - mean_absolute_error: 52.4084 - val_loss: 10690.7183 - val_mean_absolute_error: 51.0478
# Epoch 336/1000
#  - 23s - loss: 11685.0562 - mean_absolute_error: 50.5828 - val_loss: 10736.1402 - val_mean_absolute_error: 50.5608
# Epoch 337/1000
#  - 23s - loss: 11276.4004 - mean_absolute_error: 50.6560 - val_loss: 10938.8785 - val_mean_absolute_error: 55.6468
# Epoch 338/1000
#  - 22s - loss: 11372.0802 - mean_absolute_error: 50.9147 - val_loss: 10770.6360 - val_mean_absolute_error: 48.8790
# Epoch 339/1000
#  - 23s - loss: 11506.8847 - mean_absolute_error: 50.3279 - val_loss: 10534.3281 - val_mean_absolute_error: 47.1256
# Epoch 340/1000
#  - 23s - loss: 11011.9449 - mean_absolute_error: 51.5199 - val_loss: 11593.5883 - val_mean_absolute_error: 59.8664
# Epoch 341/1000
#  - 23s - loss: 11698.6234 - mean_absolute_error: 51.3520 - val_loss: 10918.8123 - val_mean_absolute_error: 60.3153
# Epoch 342/1000
#  - 22s - loss: 11883.7960 - mean_absolute_error: 53.8675 - val_loss: 11572.9381 - val_mean_absolute_error: 65.1192
# Epoch 343/1000
#  - 23s - loss: 11066.1268 - mean_absolute_error: 50.1576 - val_loss: 11031.6326 - val_mean_absolute_error: 55.9083
# Epoch 344/1000
#  - 23s - loss: 11320.6128 - mean_absolute_error: 51.6454 - val_loss: 10332.2653 - val_mean_absolute_error: 50.2202
# Epoch 345/1000
#  - 22s - loss: 10694.9057 - mean_absolute_error: 50.0033 - val_loss: 26910.9104 - val_mean_absolute_error: 79.8719
# Epoch 346/1000
#  - 23s - loss: 11110.1166 - mean_absolute_error: 49.1184 - val_loss: 10537.4994 - val_mean_absolute_error: 54.7798
# Epoch 347/1000
#  - 23s - loss: 11183.7801 - mean_absolute_error: 52.1692 - val_loss: 10089.6759 - val_mean_absolute_error: 47.6596
# Epoch 348/1000
#  - 23s - loss: 11009.0714 - mean_absolute_error: 50.7210 - val_loss: 10173.1452 - val_mean_absolute_error: 50.9742
# Epoch 349/1000
#  - 22s - loss: 10873.2394 - mean_absolute_error: 48.1460 - val_loss: 14341.3899 - val_mean_absolute_error: 57.4535
# Epoch 350/1000
#  - 23s - loss: 10847.8270 - mean_absolute_error: 47.9457 - val_loss: 10424.7300 - val_mean_absolute_error: 55.4277
# Epoch 351/1000
#  - 23s - loss: 10558.5257 - mean_absolute_error: 48.4807 - val_loss: 9813.9432 - val_mean_absolute_error: 45.1041
# Epoch 352/1000
#  - 23s - loss: 10995.2231 - mean_absolute_error: 48.4038 - val_loss: 10344.9312 - val_mean_absolute_error: 54.8874
# Epoch 353/1000
#  - 22s - loss: 10743.8732 - mean_absolute_error: 48.3584 - val_loss: 10045.5187 - val_mean_absolute_error: 53.2461
# Epoch 354/1000
#  - 23s - loss: 10389.3189 - mean_absolute_error: 48.1496 - val_loss: 18512.7679 - val_mean_absolute_error: 70.9948
# Epoch 355/1000
#  - 23s - loss: 10637.4624 - mean_absolute_error: 48.6051 - val_loss: 15802.4901 - val_mean_absolute_error: 87.8257
# Epoch 356/1000
#  - 23s - loss: 10595.2148 - mean_absolute_error: 50.7210 - val_loss: 10247.1949 - val_mean_absolute_error: 52.2278
# Epoch 357/1000
#  - 22s - loss: 10820.8631 - mean_absolute_error: 51.9492 - val_loss: 11939.4522 - val_mean_absolute_error: 65.8421
# Epoch 358/1000
#  - 23s - loss: 10490.4895 - mean_absolute_error: 48.6691 - val_loss: 9702.1869 - val_mean_absolute_error: 48.7524
# Epoch 359/1000
#  - 23s - loss: 10502.5242 - mean_absolute_error: 51.3524 - val_loss: 10536.0326 - val_mean_absolute_error: 57.2820
# Epoch 360/1000
#  - 22s - loss: 10356.7675 - mean_absolute_error: 47.8562 - val_loss: 18572.0456 - val_mean_absolute_error: 60.6557
# Epoch 361/1000
#  - 23s - loss: 10429.2318 - mean_absolute_error: 48.1516 - val_loss: 9486.0662 - val_mean_absolute_error: 46.0217
# Epoch 362/1000
#  - 23s - loss: 10639.0968 - mean_absolute_error: 49.5028 - val_loss: 10594.2250 - val_mean_absolute_error: 59.3676
# Epoch 363/1000
#  - 23s - loss: 10452.0830 - mean_absolute_error: 47.8412 - val_loss: 9997.5455 - val_mean_absolute_error: 55.9204
# Epoch 364/1000
#  - 22s - loss: 10183.8152 - mean_absolute_error: 48.0480 - val_loss: 9971.1642 - val_mean_absolute_error: 52.0859
# Epoch 365/1000
#  - 23s - loss: 10505.9953 - mean_absolute_error: 50.7578 - val_loss: 14974.6382 - val_mean_absolute_error: 90.8365
# Epoch 366/1000
#  - 23s - loss: 10565.3056 - mean_absolute_error: 49.3344 - val_loss: 10179.3229 - val_mean_absolute_error: 52.7190
# Epoch 367/1000
#  - 23s - loss: 10186.8685 - mean_absolute_error: 48.0450 - val_loss: 16110.7630 - val_mean_absolute_error: 65.1294
# Epoch 368/1000
#  - 22s - loss: 9883.9233 - mean_absolute_error: 48.3331 - val_loss: 10451.7507 - val_mean_absolute_error: 57.3550
# Epoch 369/1000
#  - 23s - loss: 10222.2887 - mean_absolute_error: 50.0254 - val_loss: 10206.0000 - val_mean_absolute_error: 59.9419
# ...
#  - 22s - loss: 416.6401 - mean_absolute_error: 12.7059 - val_loss: 780.3202 - val_mean_absolute_error: 18.2837
# Epoch 875/1000
#  - 23s - loss: 520.7267 - mean_absolute_error: 14.4207 - val_loss: 855.8608 - val_mean_absolute_error: 18.4537
# Epoch 876/1000
#  - 23s - loss: 430.8469 - mean_absolute_error: 13.3233 - val_loss: 727.4851 - val_mean_absolute_error: 14.9861
# Epoch 877/1000
#  - 23s - loss: 413.6684 - mean_absolute_error: 12.3778 - val_loss: 769.6186 - val_mean_absolute_error: 16.1899
# Epoch 878/1000
#  - 22s - loss: 391.2469 - mean_absolute_error: 11.7948 - val_loss: 704.2407 - val_mean_absolute_error: 14.4317
# Epoch 879/1000
#  - 23s - loss: 395.9754 - mean_absolute_error: 12.0899 - val_loss: 770.4453 - val_mean_absolute_error: 16.7632
# Epoch 880/1000
#  - 23s - loss: 416.9343 - mean_absolute_error: 12.7223 - val_loss: 716.8374 - val_mean_absolute_error: 14.7720
# Epoch 881/1000
#  - 23s - loss: 393.6006 - mean_absolute_error: 12.0025 - val_loss: 697.1150 - val_mean_absolute_error: 14.5173
# Epoch 882/1000
#  - 22s - loss: 392.8256 - mean_absolute_error: 12.1353 - val_loss: 784.9491 - val_mean_absolute_error: 17.4735
# Epoch 883/1000
#  - 23s - loss: 549.8465 - mean_absolute_error: 15.8891 - val_loss: 882.0797 - val_mean_absolute_error: 19.2965
# Epoch 884/1000
#  - 23s - loss: 501.4577 - mean_absolute_error: 12.8872 - val_loss: 792.7306 - val_mean_absolute_error: 15.7419
# Epoch 885/1000
#  - 23s - loss: 572.4867 - mean_absolute_error: 13.9370 - val_loss: 1326.2709 - val_mean_absolute_error: 28.9769
# Epoch 886/1000
#  - 23s - loss: 471.9158 - mean_absolute_error: 14.7800 - val_loss: 756.1344 - val_mean_absolute_error: 15.7381
# Epoch 887/1000
#  - 23s - loss: 396.4984 - mean_absolute_error: 12.4292 - val_loss: 1196.4609 - val_mean_absolute_error: 25.0572
# Epoch 888/1000
#  - 23s - loss: 416.5680 - mean_absolute_error: 13.1178 - val_loss: 1919.7690 - val_mean_absolute_error: 33.5025
# Epoch 889/1000
#  - 22s - loss: 406.3393 - mean_absolute_error: 12.9035 - val_loss: 838.1181 - val_mean_absolute_error: 19.0123
# Epoch 890/1000
#  - 23s - loss: 454.3099 - mean_absolute_error: 13.2399 - val_loss: 710.6653 - val_mean_absolute_error: 15.5583
# Epoch 891/1000
#  - 23s - loss: 386.7457 - mean_absolute_error: 12.4459 - val_loss: 1378.0012 - val_mean_absolute_error: 23.2430
# Epoch 892/1000
#  - 23s - loss: 557.0953 - mean_absolute_error: 15.3703 - val_loss: 1023.1745 - val_mean_absolute_error: 19.8006
# Epoch 893/1000
#  - 22s - loss: 502.7048 - mean_absolute_error: 14.3526 - val_loss: 783.9771 - val_mean_absolute_error: 16.1289
# Epoch 894/1000
#  - 23s - loss: 407.0023 - mean_absolute_error: 12.4460 - val_loss: 1667.3944 - val_mean_absolute_error: 22.6623
# Epoch 895/1000
#  - 23s - loss: 370.4278 - mean_absolute_error: 11.8305 - val_loss: 852.6185 - val_mean_absolute_error: 17.3352
# Epoch 896/1000
#  - 23s - loss: 365.7258 - mean_absolute_error: 11.5808 - val_loss: 705.9902 - val_mean_absolute_error: 14.3485
# Epoch 897/1000
#  - 22s - loss: 378.2125 - mean_absolute_error: 11.8735 - val_loss: 705.6041 - val_mean_absolute_error: 15.0838
# Epoch 898/1000
#  - 23s - loss: 563.7882 - mean_absolute_error: 15.0149 - val_loss: 1694.6659 - val_mean_absolute_error: 25.2542
# Epoch 899/1000
#  - 23s - loss: 382.8660 - mean_absolute_error: 12.3832 - val_loss: 808.4312 - val_mean_absolute_error: 16.1421
# Epoch 900/1000
#  - 22s - loss: 466.4825 - mean_absolute_error: 13.1183 - val_loss: 2575.0571 - val_mean_absolute_error: 25.9674
# Epoch 901/1000
#  - 23s - loss: 516.2995 - mean_absolute_error: 13.2133 - val_loss: 3969.8722 - val_mean_absolute_error: 40.0396
# Epoch 902/1000
#  - 23s - loss: 699.8959 - mean_absolute_error: 16.6756 - val_loss: 1431.6891 - val_mean_absolute_error: 25.5240
# Epoch 903/1000
#  - 23s - loss: 403.8875 - mean_absolute_error: 13.0206 - val_loss: 948.0264 - val_mean_absolute_error: 19.3848
# Epoch 904/1000
#  - 22s - loss: 345.2731 - mean_absolute_error: 11.4567 - val_loss: 909.6062 - val_mean_absolute_error: 19.5974
# Epoch 905/1000
#  - 23s - loss: 368.1356 - mean_absolute_error: 12.5859 - val_loss: 888.9898 - val_mean_absolute_error: 19.5508
# Epoch 906/1000
#  - 23s - loss: 338.3601 - mean_absolute_error: 11.0078 - val_loss: 709.8004 - val_mean_absolute_error: 16.0385
# Epoch 907/1000
#  - 23s - loss: 334.6855 - mean_absolute_error: 11.1608 - val_loss: 678.2296 - val_mean_absolute_error: 14.3029
# Epoch 908/1000
#  - 22s - loss: 322.9301 - mean_absolute_error: 10.6055 - val_loss: 705.8963 - val_mean_absolute_error: 14.6096
# Epoch 909/1000
#  - 23s - loss: 422.0669 - mean_absolute_error: 13.4232 - val_loss: 931.7888 - val_mean_absolute_error: 20.8141
# Epoch 910/1000
#  - 23s - loss: 936.0598 - mean_absolute_error: 19.0072 - val_loss: 2338.0205 - val_mean_absolute_error: 30.9309
# Epoch 911/1000
#  - 23s - loss: 490.5377 - mean_absolute_error: 13.3510 - val_loss: 1457.3488 - val_mean_absolute_error: 22.1269
# Epoch 912/1000
#  - 22s - loss: 386.2772 - mean_absolute_error: 12.4031 - val_loss: 690.2957 - val_mean_absolute_error: 15.0603
# Epoch 913/1000
#  - 23s - loss: 327.0125 - mean_absolute_error: 10.8052 - val_loss: 677.0498 - val_mean_absolute_error: 14.6794
# Epoch 914/1000
#  - 23s - loss: 318.1920 - mean_absolute_error: 10.6472 - val_loss: 688.4631 - val_mean_absolute_error: 14.5291
# Epoch 915/1000
#  - 23s - loss: 354.4963 - mean_absolute_error: 12.3166 - val_loss: 734.2500 - val_mean_absolute_error: 15.0207
# Epoch 916/1000
#  - 23s - loss: 322.8378 - mean_absolute_error: 10.8570 - val_loss: 741.5803 - val_mean_absolute_error: 15.7950
# Epoch 917/1000
#  - 23s - loss: 303.0059 - mean_absolute_error: 10.9813 - val_loss: 652.2902 - val_mean_absolute_error: 13.2242
# Epoch 918/1000
#  - 23s - loss: 305.2818 - mean_absolute_error: 10.5240 - val_loss: 667.5860 - val_mean_absolute_error: 14.3107
# Epoch 919/1000
#  - 22s - loss: 340.4212 - mean_absolute_error: 11.7144 - val_loss: 836.1421 - val_mean_absolute_error: 19.3332
# Epoch 920/1000
#  - 23s - loss: 331.4465 - mean_absolute_error: 10.9940 - val_loss: 1097.8197 - val_mean_absolute_error: 18.7740
# Epoch 921/1000
#  - 23s - loss: 323.4892 - mean_absolute_error: 10.9297 - val_loss: 1627.4915 - val_mean_absolute_error: 25.4644
# Epoch 922/1000
#  - 23s - loss: 285.2099 - mean_absolute_error: 10.2125 - val_loss: 696.4021 - val_mean_absolute_error: 14.3263
# Epoch 923/1000
#  - 22s - loss: 302.9278 - mean_absolute_error: 10.4776 - val_loss: 1220.1380 - val_mean_absolute_error: 24.8995
# Epoch 924/1000
#  - 23s - loss: 577.0445 - mean_absolute_error: 15.7497 - val_loss: 2867.3235 - val_mean_absolute_error: 29.3026
# Epoch 925/1000
#  - 23s - loss: 336.3558 - mean_absolute_error: 11.5574 - val_loss: 667.4120 - val_mean_absolute_error: 14.0162
# Epoch 926/1000
#  - 23s - loss: 329.5205 - mean_absolute_error: 11.1839 - val_loss: 696.3334 - val_mean_absolute_error: 16.4115
# Epoch 927/1000
#  - 22s - loss: 307.0341 - mean_absolute_error: 10.8742 - val_loss: 724.5466 - val_mean_absolute_error: 16.6095
# Epoch 928/1000
#  - 23s - loss: 283.5365 - mean_absolute_error: 10.4704 - val_loss: 992.7136 - val_mean_absolute_error: 20.0871
# Epoch 929/1000
#  - 23s - loss: 305.7475 - mean_absolute_error: 10.8011 - val_loss: 790.3967 - val_mean_absolute_error: 16.3040
# Epoch 930/1000
#  - 23s - loss: 483.7681 - mean_absolute_error: 10.1857 - val_loss: 779.5677 - val_mean_absolute_error: 16.9948
# Epoch 931/1000
#  - 23s - loss: 651.3248 - mean_absolute_error: 15.7048 - val_loss: 891.3390 - val_mean_absolute_error: 18.6253
# Epoch 932/1000
#  - 23s - loss: 353.5302 - mean_absolute_error: 12.1228 - val_loss: 708.1979 - val_mean_absolute_error: 17.2072
# Epoch 933/1000
#  - 23s - loss: 429.0302 - mean_absolute_error: 12.0242 - val_loss: 775.7381 - val_mean_absolute_error: 16.2051
# Epoch 934/1000
#  - 22s - loss: 555.3999 - mean_absolute_error: 13.2633 - val_loss: 693.8731 - val_mean_absolute_error: 14.4121
# Epoch 935/1000
#  - 23s - loss: 290.5304 - mean_absolute_error: 10.4370 - val_loss: 662.4733 - val_mean_absolute_error: 14.3622
# Epoch 936/1000
#  - 23s - loss: 317.9669 - mean_absolute_error: 11.3124 - val_loss: 747.2763 - val_mean_absolute_error: 16.4198
# Epoch 937/1000
#  - 23s - loss: 271.1506 - mean_absolute_error: 10.1707 - val_loss: 622.6210 - val_mean_absolute_error: 14.0128
# Epoch 938/1000
#  - 22s - loss: 337.7820 - mean_absolute_error: 12.2367 - val_loss: 668.7199 - val_mean_absolute_error: 15.1711
# Epoch 939/1000
#  - 23s - loss: 269.3666 - mean_absolute_error: 10.4065 - val_loss: 648.4100 - val_mean_absolute_error: 14.0785
# Epoch 940/1000
#  - 23s - loss: 346.9724 - mean_absolute_error: 11.8366 - val_loss: 1318.7332 - val_mean_absolute_error: 27.5204
# Epoch 941/1000
#  - 23s - loss: 373.6464 - mean_absolute_error: 12.1548 - val_loss: 998.8358 - val_mean_absolute_error: 23.4699
# Epoch 942/1000
#  - 22s - loss: 428.3586 - mean_absolute_error: 14.1516 - val_loss: 611.9002 - val_mean_absolute_error: 13.6523
# Epoch 943/1000
#  - 23s - loss: 265.6341 - mean_absolute_error: 10.2347 - val_loss: 608.5469 - val_mean_absolute_error: 14.4356
# Epoch 944/1000
#  - 23s - loss: 352.7034 - mean_absolute_error: 11.7190 - val_loss: 784.6693 - val_mean_absolute_error: 18.0033
# Epoch 945/1000
#  - 23s - loss: 297.5137 - mean_absolute_error: 11.1846 - val_loss: 730.2347 - val_mean_absolute_error: 18.4388
# Epoch 946/1000
#  - 23s - loss: 387.5635 - mean_absolute_error: 12.5963 - val_loss: 785.9711 - val_mean_absolute_error: 15.6379
# Epoch 947/1000
#  - 23s - loss: 293.8739 - mean_absolute_error: 11.4756 - val_loss: 767.9590 - val_mean_absolute_error: 14.9480
# Epoch 948/1000
#  - 23s - loss: 301.5869 - mean_absolute_error: 10.2240 - val_loss: 820.6611 - val_mean_absolute_error: 18.3628
# Epoch 949/1000
#  - 22s - loss: 307.0270 - mean_absolute_error: 11.3903 - val_loss: 690.5880 - val_mean_absolute_error: 16.3307
# Epoch 950/1000
#  - 23s - loss: 298.9766 - mean_absolute_error: 11.0295 - val_loss: 697.3846 - val_mean_absolute_error: 15.0173
# Epoch 951/1000
#  - 23s - loss: 276.0789 - mean_absolute_error: 10.6418 - val_loss: 640.6659 - val_mean_absolute_error: 14.1527
# Epoch 952/1000
#  - 23s - loss: 241.7500 - mean_absolute_error: 9.7886 - val_loss: 615.0231 - val_mean_absolute_error: 13.8940
# Epoch 953/1000
#  - 22s - loss: 223.0992 - mean_absolute_error: 9.0309 - val_loss: 578.6690 - val_mean_absolute_error: 12.1149
# Epoch 954/1000
#  - 23s - loss: 228.4597 - mean_absolute_error: 9.2953 - val_loss: 597.5779 - val_mean_absolute_error: 12.8073
# Epoch 955/1000
#  - 23s - loss: 344.9686 - mean_absolute_error: 12.3446 - val_loss: 887.0562 - val_mean_absolute_error: 17.2982
# Epoch 956/1000
#  - 23s - loss: 408.3298 - mean_absolute_error: 11.7787 - val_loss: 742.5376 - val_mean_absolute_error: 17.9607
# Epoch 957/1000
#  - 22s - loss: 347.2435 - mean_absolute_error: 12.5526 - val_loss: 1331.8422 - val_mean_absolute_error: 23.2332
# Epoch 958/1000
#  - 23s - loss: 275.8360 - mean_absolute_error: 10.3610 - val_loss: 693.3766 - val_mean_absolute_error: 14.4472
# Epoch 959/1000
#  - 23s - loss: 325.9158 - mean_absolute_error: 11.7100 - val_loss: 722.0340 - val_mean_absolute_error: 16.3459
# Epoch 960/1000
#  - 23s - loss: 274.4327 - mean_absolute_error: 10.8352 - val_loss: 584.7103 - val_mean_absolute_error: 12.4583
# Epoch 961/1000
#  - 23s - loss: 244.9321 - mean_absolute_error: 9.8363 - val_loss: 625.3313 - val_mean_absolute_error: 14.4862
# Epoch 962/1000
#  - 23s - loss: 248.5706 - mean_absolute_error: 9.9510 - val_loss: 595.5127 - val_mean_absolute_error: 12.7118
# Epoch 963/1000
#  - 23s - loss: 329.5630 - mean_absolute_error: 11.0414 - val_loss: 649.9973 - val_mean_absolute_error: 15.1596
# Epoch 964/1000
#  - 22s - loss: 233.6073 - mean_absolute_error: 9.9338 - val_loss: 566.0973 - val_mean_absolute_error: 12.3790
# Epoch 965/1000
#  - 23s - loss: 272.8677 - mean_absolute_error: 10.9025 - val_loss: 825.4294 - val_mean_absolute_error: 18.3619
# Epoch 966/1000
#  - 23s - loss: 224.2109 - mean_absolute_error: 9.1592 - val_loss: 714.9512 - val_mean_absolute_error: 17.2153
# Epoch 967/1000
#  - 23s - loss: 373.1904 - mean_absolute_error: 12.5313 - val_loss: 585.2542 - val_mean_absolute_error: 12.3827
# Epoch 968/1000
#  - 22s - loss: 387.5417 - mean_absolute_error: 13.1468 - val_loss: 928.7404 - val_mean_absolute_error: 19.3649
# Epoch 969/1000
#  - 23s - loss: 305.4558 - mean_absolute_error: 11.6917 - val_loss: 806.4618 - val_mean_absolute_error: 17.2712
# Epoch 970/1000
#  - 23s - loss: 262.3212 - mean_absolute_error: 10.1555 - val_loss: 635.6307 - val_mean_absolute_error: 13.6697
# Epoch 971/1000
#  - 23s - loss: 242.1663 - mean_absolute_error: 9.9067 - val_loss: 614.4792 - val_mean_absolute_error: 12.7229
# Epoch 972/1000
#  - 22s - loss: 348.2855 - mean_absolute_error: 10.6001 - val_loss: 634.7335 - val_mean_absolute_error: 13.8990
# Epoch 973/1000
#  - 23s - loss: 260.8324 - mean_absolute_error: 10.8063 - val_loss: 613.3674 - val_mean_absolute_error: 14.5957
# Epoch 974/1000
#  - 23s - loss: 221.8483 - mean_absolute_error: 9.1879 - val_loss: 568.9500 - val_mean_absolute_error: 12.9763
# Epoch 975/1000
#  - 23s - loss: 201.7543 - mean_absolute_error: 8.5649 - val_loss: 567.3642 - val_mean_absolute_error: 12.2855
# Epoch 976/1000
#  - 23s - loss: 365.4400 - mean_absolute_error: 12.5770 - val_loss: 2403.9506 - val_mean_absolute_error: 28.5473
# Epoch 977/1000
#  - 23s - loss: 492.8404 - mean_absolute_error: 14.6143 - val_loss: 664.2807 - val_mean_absolute_error: 14.0285
# Epoch 978/1000
#  - 23s - loss: 288.1966 - mean_absolute_error: 10.3714 - val_loss: 564.9017 - val_mean_absolute_error: 12.1594
# Epoch 979/1000
#  - 22s - loss: 218.0269 - mean_absolute_error: 9.0252 - val_loss: 585.1691 - val_mean_absolute_error: 12.8921
# Epoch 980/1000
#  - 23s - loss: 333.8090 - mean_absolute_error: 11.2149 - val_loss: 1807.9575 - val_mean_absolute_error: 29.0796
# Epoch 981/1000
#  - 23s - loss: 395.4478 - mean_absolute_error: 13.7090 - val_loss: 962.3872 - val_mean_absolute_error: 16.9236
# Epoch 982/1000
#  - 23s - loss: 543.0148 - mean_absolute_error: 13.0616 - val_loss: 1133.6237 - val_mean_absolute_error: 18.7702
# Epoch 983/1000
#  - 22s - loss: 335.9846 - mean_absolute_error: 10.9753 - val_loss: 647.1110 - val_mean_absolute_error: 15.9965
# Epoch 984/1000
#  - 23s - loss: 270.0184 - mean_absolute_error: 10.3541 - val_loss: 2325.4582 - val_mean_absolute_error: 23.5291
# Epoch 985/1000
#  - 23s - loss: 257.0642 - mean_absolute_error: 10.3998 - val_loss: 735.4415 - val_mean_absolute_error: 16.4175
# Epoch 986/1000
#  - 23s - loss: 240.8784 - mean_absolute_error: 9.4808 - val_loss: 616.4320 - val_mean_absolute_error: 13.4941
# Epoch 987/1000
#  - 22s - loss: 202.5371 - mean_absolute_error: 8.6561 - val_loss: 590.1804 - val_mean_absolute_error: 12.8365
# Epoch 988/1000
#  - 23s - loss: 196.8066 - mean_absolute_error: 8.4407 - val_loss: 561.4164 - val_mean_absolute_error: 12.4336
# Epoch 989/1000
#  - 23s - loss: 389.1263 - mean_absolute_error: 11.5212 - val_loss: 990.0009 - val_mean_absolute_error: 20.3660
# Epoch 990/1000
#  - 23s - loss: 240.5161 - mean_absolute_error: 9.6187 - val_loss: 601.7037 - val_mean_absolute_error: 13.8963
# Epoch 991/1000
#  - 23s - loss: 273.7849 - mean_absolute_error: 9.4433 - val_loss: 650.0349 - val_mean_absolute_error: 13.5932
# Epoch 992/1000
#  - 23s - loss: 249.2677 - mean_absolute_error: 9.6317 - val_loss: 607.1727 - val_mean_absolute_error: 12.3657
# Epoch 993/1000
#  - 23s - loss: 218.6972 - mean_absolute_error: 8.9055 - val_loss: 595.6236 - val_mean_absolute_error: 12.5082
# Epoch 994/1000
#  - 22s - loss: 481.3538 - mean_absolute_error: 14.0624 - val_loss: 1288.5050 - val_mean_absolute_error: 25.9874
# Epoch 995/1000
#  - 23s - loss: 284.5654 - mean_absolute_error: 11.4835 - val_loss: 821.1810 - val_mean_absolute_error: 17.0279
# Epoch 996/1000
#  - 23s - loss: 221.3398 - mean_absolute_error: 9.1205 - val_loss: 581.0652 - val_mean_absolute_error: 12.1962
# Epoch 997/1000
#  - 23s - loss: 194.3603 - mean_absolute_error: 8.7031 - val_loss: 658.6101 - val_mean_absolute_error: 14.4728
# Epoch 998/1000
#  - 22s - loss: 183.0720 - mean_absolute_error: 8.1610 - val_loss: 585.5186 - val_mean_absolute_error: 12.9124
# Epoch 999/1000
#  - 23s - loss: 185.7079 - mean_absolute_error: 8.2296 - val_loss: 562.9171 - val_mean_absolute_error: 12.5333
# Epoch 1000/1000
#  - 23s - loss: 247.5088 - mean_absolute_error: 10.1937 - val_loss: 953.5443 - val_mean_absolute_error: 18.0641

# %%
import pickle
file_pickle = open('trainHistoryDictV1_noisy', 'wb') 
pickle.dump(hist, file_pickle)
file_pickle.close()

#file_pickle = open('trainHistoryDictV3', 'rb')
#hist = pickle.load(file_pickle)


print(hist.history.keys())

index = 0
fix, ax = plt.subplots(2,1, figsize=(20,8))
#plt.yscale('log')
loss_train = hist.history['loss']
loss_val = hist.history['val_loss']
ax[0].plot(loss_train[0:50])
ax[0].set_title('Training Error : MSE')
ax[0].set(xlabel = 'EPOCHS', ylabel = 'MSE')
ax[1].plot(loss_val[0:50])
ax[1].set_title('Validation Error : MSE')
ax[1].set(xlabel = 'EPOCHS', ylabel = 'MSE')


#image_batch, mask_batch = next(my_generator(train_images, train_labels, 5))
fix, ax = plt.subplots(3,3, figsize=(8,10))
for i in range(3):
    temp = model.predict( np.expand_dims( np.expand_dims(train_images[i*4,:,:,0], axis = 0), axis = 3 ))
    #ax[i,0].imshow(train_images[i,:,:,0], cmap='gray')
    #ax[i,1].imshow(train_labels[i,:,:,0], cmap='gray')    
    #ax[i,2].imshow(np.squeeze(temp), cmap='gray')
    ax[i,0].imshow(adjust_gamma(train_images[i*4,:,:,0],0.6), cmap='gray')
    ax[i,1].imshow(adjust_gamma(train_labels[i*4,:,:,0],1.5), cmap='gray')    
    ax[i,2].imshow(adjust_gamma(np.squeeze(temp),1.5), cmap='gray')    
ax[0,0].set_title('Input')
ax[0,1].set_title('Ground Truth')
ax[0,2].set_title('Output')
plt.show()
################ Left Column :
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'loss', 'mean_absolute_error'])

# %% [markdown]
# # Test

# %%
#model.load_weights('rfg_v4.h5')
#model.compile(Adam(lr = 0.01), loss='mean_squared_error', metrics=['mean_absolute_error'])

loss, acc = model.evaluate(test_images,test_labels)
print(loss)
print(acc)
fix, ax = plt.subplots(3,3, figsize=(8,10))
for i in range(3):      
    temp = model.predict( np.expand_dims( np.expand_dims(test_images[i,:,:,0], axis = 0), axis = 3 ))
    #ax[i,0].imshow(test_images[i,:,:,0], cmap='gray')
    #ax[i,1].imshow(test_labels[i,:,:,0], cmap='gray')          
    #ax[i,2].imshow(np.squeeze(temp), cmap='gray')
    ax[i,0].imshow(adjust_gamma(test_images[i,:,:,0], 0.6) , cmap='gray')
    ax[i,1].imshow(adjust_gamma(test_labels[i,:,:,0], 1.5) , cmap='gray')          
    ax[i,2].imshow(adjust_gamma(np.squeeze(temp) , 1.5) , cmap='gray')    
ax[0,0].set_title('Input')
ax[0,1].set_title('Ground Truth')
ax[0,2].set_title('Output')

plt.show()
# Out:
# 50/50 [==============================] - 0s 5ms/step
# 953.544345703125
# 18.064119033813476
