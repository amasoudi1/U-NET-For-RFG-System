# %% [markdown]
# <a href="https://colab.research.google.com/github/amasoudi1/U-NET-For-RFG-System/blob/master/UNET_Fixed_Gantry2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pyyaml  # pyyaml is an optional
# !pip install -U -q PyDrive  # PyDrive you can upload/download read and write data

# %%
#import tensorflow as tf
#from tensorflow.keras import layers
#from tensorflow.python.client import device_lib


#print(tf.VERSION)
#print(tf.keras.__version__)
#device_lib.list_local_devices()

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd /content/gdrive/'My Drive'/'Colab Notebooks'/
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
ls
# Out:
# data_label/           rfg_v2.h5                 train_data_128/
# data_reconstruction/  rfg_v3.h5                 train_images_128/
# FbpConvNet.ipynb      test_data/                train_images_norm_128/
# model100.h5           test_data_128/            training/
# model100v2.h5         test_images_128/          train_label_conv_rfg_100/
# model100v3.h5         test_images_norm_128/     train_labels_128/
# model100v4.h5         test_label_conv_rfg_100/  train_labels_norm_128/
# model100v5.h5         test_labels_128/          train_rec_conv_rfg_100/
# model1.h5             test_labels_norm_128/     UNET_Fixed_Gantry2.ipynb
# model.h5              test_rec_conv_rfg_100/    Untitled0.ipynb
# rfg.h5                train_data/

# %%
import os
import sys

try:
 device_name = os.environ['COLAB_TPU_ADDR']
 TPU_ADDRESS = 'grpc://' + device_name
 print('Found TPU at: {}'.format(TPU_ADDRESS))
except KeyError:
 print('TPU not found')
# Out:
# TPU not found

# %%
#from tensorflow.keras.models import *
#from tensorflow.keras.layers import *
#from tensorflow.keras.optimizers import *
#from tensorflow.keras.initializers import *
#from tf.keras.callbacks import ModelCheckpoint, LearningRateScheduler
#from tf.keras import backend as keras

from keras.models import Model
from keras.layers import *
from keras.optimizers import *
from keras.regularizers import l2
from keras.preprocessing.image import ImageDataGenerator
import keras.backend as K
from keras.callbacks import LearningRateScheduler, ModelCheckpoint ,Callback
from keras.initializers import *

import numpy as np
import scipy.io as sc
import os
import sys
from sklearn.utils import shuffle
#from scipy.ndimage import imread
from imageio import imread
#from scipy.misc import imresize
import matplotlib.pyplot as plt

#np.random.seed(0)
#tf.set_random_seed(0)
#print(tf.VERSION)
#print(tf.keras.__version__)


train_images = np.zeros(shape=(1800,100,100,1))
train_labels = np.zeros(shape=(1800,100,100,1))

test_images = np.zeros(shape=(200,100,100,1))
test_labels = np.zeros(shape=(200,100,100,1))

indx = np.arange(2000)
np.random.shuffle(indx)
print(indx[1980:2000])

# --- get training data ---
images_location = "./data_reconstruction/"
labels_location = "./data_label/"

for i in range(1800):    
    image_temp = sc.loadmat(images_location + str(indx[i]+1) + ".mat")    
    train_images[i,:,:]   = np.expand_dims(np.array(image_temp['r']),axis=2)
    
    label_temp = sc.loadmat(labels_location + str(indx[i]+1) + ".mat")    
    train_labels[i,:,:]   = np.expand_dims(np.array(label_temp['t']),axis=2)
    
                
# --- get test data ---
#images_location = "./test_rec_conv_rfg_100/"
#labels_location = "./test_label_conv_rfg_100/"
      
counter = 0  
for i in range(1800,2000):      
    image_temp = sc.loadmat(images_location + str(indx[i]+1) + ".mat")    
    test_images[counter,:,:]   = np.expand_dims(np.array(image_temp['r']),axis=2)
    
    label_temp = sc.loadmat(labels_location + str(indx[i]+1) + ".mat")    
    test_labels[counter,:,:]   = np.expand_dims(np.array(label_temp['t']),axis=2)
    counter += 1
      
#train_images = 1*(train_images - train_images.min()) / (train_images.max() - train_images.min())
#train_labels = 1*(train_labels - train_labels.min()) / (train_labels.max() - train_labels.min())      
      
print("Done With Data")
fix, ax = plt.subplots(5,2, figsize=(8,20))
for i in range(5):
    ax[i,0].imshow(train_images[i,:,:,0], cmap='gray')
    ax[i,1].imshow(train_labels[i,:,:,0], cmap='gray')
plt.show()

#fix, ax = plt.subplots(1,2, figsize=(8,20))
#ax[0].imshow(train_images[0,:,:,0], cmap='gray')
#ax[1].imshow(train_labels[0,:,:,0], cmap='gray')
#plt.show()
# Out:
# [1314 1587  653 1764 1299 1967 1035 1747  861  729  647  105  534 1871
#   335 1362  342 1389  988 1077]
# Done With Data

# %%
# Defining
SEED = 42
#initializer = RandomNormal(mean=0.0, stddev=0.05, seed = SEED) 
initializer = glorot_normal(seed = SEED) 
inputs = Input(shape=(100,100,1))  # Returns a placeholder tensor

### Layers :
# LEVEL 1
L10 = Conv2D(1, (1, 1), activation='relu', padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(inputs)
L11 = Conv2D(64, (1, 1), activation='relu', padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L10)
L11 = BatchNormalization()(L11)
L12 = Conv2D(64, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L11)
L12 = BatchNormalization()(L12)
L13 = Conv2D(64, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L12)
L13 = BatchNormalization()(L13)

# LEVEL 2
L20 = MaxPooling2D(pool_size=(2, 2), padding='valid')(L13)
L21 = Conv2D(128, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L20)
L21 = BatchNormalization()(L21)
L22 = Conv2D(128, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L21)
L22 = BatchNormalization()(L22)

# LEVEL 3
L30 = MaxPooling2D(pool_size=(2, 2), padding='valid')(L22)
L31 = Conv2D(256, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L30)
L31 = BatchNormalization()(L31)
L32 = Conv2D(256, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L31)
L32 = BatchNormalization()(L32)

# LEVEL 4
L40 = MaxPooling2D(pool_size=(2, 2), padding='valid')(L32)
L41 = Conv2D(512, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L40)
L41 = BatchNormalization()(L41)
L42 = Conv2D(512, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L41)
L42 = BatchNormalization()(L42)

# LEVEL 5
L50 = MaxPooling2D(pool_size=(2, 2), padding='valid')(L42)
L51 = Conv2D(1024, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L50)
L51 = BatchNormalization()(L51)
L52 = Conv2D(1024, (3, 3), activation='relu' ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L51)
L52 = BatchNormalization()(L52)

# LEVEL 4
L43_in = Conv2DTranspose(256, (3, 3), activation='relu' , strides=(2, 2) ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L52)
#L43_in = UpSampling2D(size=(2,2))(L52)
L43_in = BatchNormalization()(L43_in)
L43 = Conv2D(512, (3, 3), activation='relu' ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(concatenate([L42,L43_in], axis = 3))
L43 = BatchNormalization()(L43)
L44 = Conv2D(512, (3, 3), activation='relu' ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L43)
L44 = BatchNormalization()(L44)

# LEVEL 3
L33_in = Conv2DTranspose(128, (3, 3), activation='relu', strides=(2, 2) ,padding='valid',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L44)
#L33_in = UpSampling2D(size=(2,2))(L44)
L33_in = BatchNormalization()(L33_in)
L33 = Conv2D(256, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(concatenate([L32,L33_in], axis = 3))
L33 = BatchNormalization()(L33)
L34 = Conv2D(256, (3, 3), activation='relu' ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L33)
L34 = BatchNormalization()(L34)

# LEVEL 2
L23_in = Conv2DTranspose(64, (3, 3), activation='relu' , strides=(2, 2) ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L34)
#L23_in = UpSampling2D(size=(2,2))(L34)
L23_in = BatchNormalization()(L23_in)
L23 = Conv2D(128, (3, 3), activation='relu' ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(concatenate([L22,L23_in], axis = 3))
L23 = BatchNormalization()(L23)
L24 = Conv2D(128, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L23)
L24 = BatchNormalization()(L24)

# LEVEL 1
L14_in = Conv2DTranspose(32, (3, 3), activation='relu' , strides=(2, 2) ,padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L24)
#L14_in = UpSampling2D(size=(2,2))(L24)
L14_in = BatchNormalization()(L14_in)
L14 = Conv2D(64, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(concatenate([L13,L14_in], axis = 3))
L14 = BatchNormalization()(L14)
L15 = Conv2D(64, (3, 3), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L14)
L15 = BatchNormalization()(L15)
L16 = Conv2D(1, (1, 1), activation='relu' , padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(L15)
feed_forward = Add()([L10,L16])
L17 = Conv2D(1, (1, 1), padding='same',use_bias=True, kernel_initializer= initializer, bias_initializer='zeros')(feed_forward)


model = Model(inputs=inputs, outputs=L17)
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 100, 100, 1)  0
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 100, 100, 1)  2           input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 100, 100, 64) 128         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 100, 100, 64) 256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 100, 100, 64) 36928       batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 100, 100, 64) 256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 100, 100, 64) 36928       batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 100, 100, 64) 256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 50, 50, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 50, 50, 128)  73856       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 50, 50, 128)  512         conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 50, 50, 128)  147584      batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 50, 50, 128)  512         conv2d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 25, 25, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 25, 25, 256)  295168      max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 25, 25, 256)  1024        conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 25, 25, 256)  590080      batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 25, 25, 256)  1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 12, 12, 256)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 12, 12, 512)  1180160     max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 12, 12, 512)  2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 12, 12, 512)  2359808     batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 12, 12, 512)  2048        conv2d_32[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 6, 6, 512)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 6, 6, 1024)   4719616     max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 6, 6, 1024)   4096        conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 6, 6, 1024)   9438208     batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 6, 6, 1024)   4096        conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 12, 12, 256)  2359552     batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 12, 12, 256)  1024        conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 12, 12, 768)  0           batch_normalization_32[0][0]
#                                                                  batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 12, 12, 512)  3539456     concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 12, 12, 512)  2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 12, 12, 512)  2359808     batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 12, 12, 512)  2048        conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 25, 25, 128)  589952      batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 25, 25, 128)  512         conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 25, 25, 384)  0           batch_normalization_30[0][0]
#                                                                  batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 25, 25, 256)  884992      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 25, 25, 256)  1024        conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 25, 25, 256)  590080      batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 25, 25, 256)  1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 50, 50, 64)   147520      batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 50, 50, 64)   256         conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 50, 50, 192)  0           batch_normalization_28[0][0]
#                                                                  batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 50, 50, 128)  221312      concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 50, 50, 128)  512         conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 50, 50, 128)  147584      batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 50, 50, 128)  512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 100, 100, 32) 36896       batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 100, 100, 32) 128         conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 100, 100, 96) 0           batch_normalization_26[0][0]
#                                                                  batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 100, 100, 64) 55360       concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 100, 100, 64) 256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 100, 100, 64) 36928       batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 100, 100, 64) 256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 100, 100, 1)  65          batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 100, 100, 1)  0           conv2d_23[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 100, 100, 1)  2           add_2[0][0]
# ==================================================================================================
# Total params: 29,873,701
# Trainable params: 29,860,837
# Non-trainable params: 12,864
# __________________________________________________________________________________________________

# %%
def my_generator(x_train, y_train, batch_size):
    data_generator = ImageDataGenerator(horizontal_flip = True, vertical_flip = True).flow(x_train, x_train, batch_size, seed=SEED)
    mask_generator = ImageDataGenerator(horizontal_flip = True, vertical_flip = True).flow(y_train, y_train, batch_size, seed=SEED)
    while True:
        x_batch, _ = data_generator.next()
        y_batch, _ = mask_generator.next()
        yield x_batch, y_batch

# %%
image_batch, mask_batch = next(my_generator(train_images, train_labels, 5))
fix, ax = plt.subplots(5,2, figsize=(8,20))
for i in range(5):
    ax[i,0].imshow(image_batch[i,:,:,0], cmap='gray')
    ax[i,1].imshow(mask_batch[i,:,:,0], cmap='gray')
plt.show()

# %%
#sgd = SGD(lr=1e-4, momentum=0.99, nesterov = True, clipvalue=0.01)
#sgd = SGD(lr=1, momentum=0.99, clipvalue=0.01)
#sgd = tf.train.MomentumOptimizer(learning_rate = 0.01, momentum=0.99)

class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))

model.compile(Adam(lr = 0.01), loss='mean_squared_error', metrics=['mean_absolute_error'])
#model.compile(sgd, loss='mean_squared_error', metrics=['mean_absolute_error'])

weight_saver = ModelCheckpoint('./rfg_v3.h5', monitor='val_loss',
                               save_best_only=True, save_weights_only=True)

#annealer = LearningRateScheduler(lambda x: 0.99 ** x)

# %%
#model.load_weights('rfg.h5')
#model.compile(Adam(lr = 0.01), loss='mean_squared_error', metrics=['mean_absolute_error'])
#loss, acc = model.evaluate(train_images,train_labels)
#print(loss)
#print(acc)

#history = LossHistory()
#hist = model.fit(train_images, train_labels, batch_size = 32, epochs = 2000, validation_data = (test_images,test_labels), 
#          shuffle = True ,verbose = 1, callbacks = [weight_saver,history])#, annealer])
hist = model.fit_generator(my_generator(train_images, train_labels, 32), validation_data = (test_images,test_labels),
                           epochs=1000, verbose=1, shuffle=True,
                           steps_per_epoch = 64,
                           callbacks = [weight_saver])#, annealer])
# Out:
# Epoch 1/1000
# 64/64 [==============================] - 32s 495ms/step - loss: 87574.1395 - mean_absolute_error: 254.0152 - val_loss: 42402.1848 - val_mean_absolute_error: 145.6646
# Epoch 2/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 36477.8895 - mean_absolute_error: 103.3582 - val_loss: 37428.9267 - val_mean_absolute_error: 109.3544
# Epoch 3/1000
# 64/64 [==============================] - 24s 380ms/step - loss: 35854.7018 - mean_absolute_error: 100.8267 - val_loss: 36917.4194 - val_mean_absolute_error: 106.8471
# Epoch 4/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 35338.3643 - mean_absolute_error: 98.4638 - val_loss: 37222.9400 - val_mean_absolute_error: 108.0049
# Epoch 5/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 35678.3320 - mean_absolute_error: 98.3225 - val_loss: 36387.0123 - val_mean_absolute_error: 102.2289
# Epoch 6/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 35344.7546 - mean_absolute_error: 96.3483 - val_loss: 36374.7141 - val_mean_absolute_error: 102.9496
# Epoch 7/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 34758.3095 - mean_absolute_error: 94.5399 - val_loss: 35727.3264 - val_mean_absolute_error: 96.4161
# Epoch 8/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 35432.4486 - mean_absolute_error: 95.5442 - val_loss: 35689.1800 - val_mean_absolute_error: 97.6345
# Epoch 9/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 34601.9261 - mean_absolute_error: 93.4390 - val_loss: 35638.5448 - val_mean_absolute_error: 98.4139
# Epoch 10/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 34704.2547 - mean_absolute_error: 93.3361 - val_loss: 35782.9203 - val_mean_absolute_error: 102.2570
# Epoch 11/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 34591.2462 - mean_absolute_error: 92.6028 - val_loss: 35459.8719 - val_mean_absolute_error: 98.6598
# Epoch 12/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 33608.4805 - mean_absolute_error: 90.1428 - val_loss: 35107.0756 - val_mean_absolute_error: 96.5207
# Epoch 13/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 34239.5152 - mean_absolute_error: 90.8774 - val_loss: 34810.7278 - val_mean_absolute_error: 94.0269
# Epoch 14/1000
# 64/64 [==============================] - 24s 377ms/step - loss: 34240.8507 - mean_absolute_error: 90.6321 - val_loss: 34913.6903 - val_mean_absolute_error: 97.1430
# Epoch 15/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 33428.6986 - mean_absolute_error: 89.8240 - val_loss: 34699.8436 - val_mean_absolute_error: 96.2079
# Epoch 16/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 33642.4771 - mean_absolute_error: 88.8988 - val_loss: 34449.8600 - val_mean_absolute_error: 94.2632
# Epoch 17/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 33300.3596 - mean_absolute_error: 88.4019 - val_loss: 34428.7531 - val_mean_absolute_error: 93.6687
# Epoch 18/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 33549.7304 - mean_absolute_error: 88.7933 - val_loss: 34179.8714 - val_mean_absolute_error: 92.6718
# Epoch 19/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 33136.2577 - mean_absolute_error: 87.8827 - val_loss: 34225.8225 - val_mean_absolute_error: 96.3582
# Epoch 20/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 33754.8017 - mean_absolute_error: 89.1907 - val_loss: 33946.0630 - val_mean_absolute_error: 92.4447
# Epoch 21/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 32087.6529 - mean_absolute_error: 84.9589 - val_loss: 34165.2678 - val_mean_absolute_error: 96.3588
# Epoch 22/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 32919.1932 - mean_absolute_error: 87.5668 - val_loss: 33908.7633 - val_mean_absolute_error: 95.6256
# Epoch 23/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 33632.0072 - mean_absolute_error: 91.4913 - val_loss: 35098.8848 - val_mean_absolute_error: 108.3337
# Epoch 24/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 33138.0474 - mean_absolute_error: 89.2154 - val_loss: 34049.7122 - val_mean_absolute_error: 100.3994
# Epoch 25/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 32263.9466 - mean_absolute_error: 86.4889 - val_loss: 33418.0013 - val_mean_absolute_error: 91.2547
# Epoch 26/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 32326.5231 - mean_absolute_error: 86.0300 - val_loss: 33435.8342 - val_mean_absolute_error: 94.0593
# Epoch 27/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 32881.6475 - mean_absolute_error: 86.1026 - val_loss: 33404.2859 - val_mean_absolute_error: 95.9604
# Epoch 28/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 31669.5746 - mean_absolute_error: 84.3702 - val_loss: 33299.9688 - val_mean_absolute_error: 94.6851
# Epoch 29/1000
# 64/64 [==============================] - 24s 377ms/step - loss: 32831.0149 - mean_absolute_error: 87.2441 - val_loss: 35303.6266 - val_mean_absolute_error: 111.1214
# Epoch 30/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 32610.8263 - mean_absolute_error: 87.5220 - val_loss: 35524.4223 - val_mean_absolute_error: 102.8420
# Epoch 31/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 31508.9834 - mean_absolute_error: 84.1345 - val_loss: 33134.7603 - val_mean_absolute_error: 95.2503
# Epoch 32/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 31582.8510 - mean_absolute_error: 84.8175 - val_loss: 34801.5402 - val_mean_absolute_error: 111.9373
# Epoch 33/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 31507.7399 - mean_absolute_error: 83.8104 - val_loss: 34447.8998 - val_mean_absolute_error: 109.5196
# Epoch 34/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 31533.6843 - mean_absolute_error: 83.4920 - val_loss: 34191.3359 - val_mean_absolute_error: 107.9113
# Epoch 35/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 31115.8342 - mean_absolute_error: 82.9452 - val_loss: 35725.1178 - val_mean_absolute_error: 120.2850
# Epoch 36/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 31853.6216 - mean_absolute_error: 84.9343 - val_loss: 32904.6797 - val_mean_absolute_error: 96.1355
# Epoch 37/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 30901.5015 - mean_absolute_error: 82.5012 - val_loss: 34129.1173 - val_mean_absolute_error: 109.6927
# Epoch 38/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 31354.4016 - mean_absolute_error: 83.9523 - val_loss: 34228.8966 - val_mean_absolute_error: 110.6956
# Epoch 39/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 31052.0620 - mean_absolute_error: 82.2718 - val_loss: 33962.7352 - val_mean_absolute_error: 108.7965
# Epoch 40/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 30999.4165 - mean_absolute_error: 81.9728 - val_loss: 32842.8089 - val_mean_absolute_error: 100.0331
# Epoch 41/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 30764.8828 - mean_absolute_error: 81.7516 - val_loss: 32887.3747 - val_mean_absolute_error: 100.6729
# Epoch 42/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 31200.0099 - mean_absolute_error: 82.4156 - val_loss: 33997.5356 - val_mean_absolute_error: 110.0006
# Epoch 43/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 30638.4239 - mean_absolute_error: 81.8789 - val_loss: 33842.6161 - val_mean_absolute_error: 110.2045
# Epoch 44/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 30502.5367 - mean_absolute_error: 81.1583 - val_loss: 32973.0972 - val_mean_absolute_error: 103.5336
# Epoch 45/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 30341.6075 - mean_absolute_error: 80.7709 - val_loss: 33206.3737 - val_mean_absolute_error: 106.6142
# Epoch 46/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 30904.6500 - mean_absolute_error: 83.1771 - val_loss: 32053.0828 - val_mean_absolute_error: 93.5373
# Epoch 47/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 30612.7283 - mean_absolute_error: 82.3320 - val_loss: 31070.3055 - val_mean_absolute_error: 83.4222
# Epoch 48/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 30427.5015 - mean_absolute_error: 82.5879 - val_loss: 65255.9189 - val_mean_absolute_error: 195.7816
# Epoch 49/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 30510.4222 - mean_absolute_error: 83.1871 - val_loss: 33931.3991 - val_mean_absolute_error: 111.8641
# Epoch 50/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 29959.4666 - mean_absolute_error: 80.8158 - val_loss: 31129.2195 - val_mean_absolute_error: 87.7848
# Epoch 51/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 30099.6661 - mean_absolute_error: 80.8959 - val_loss: 30817.6244 - val_mean_absolute_error: 84.1225
# Epoch 52/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 30036.3763 - mean_absolute_error: 79.9767 - val_loss: 32238.4377 - val_mean_absolute_error: 102.5393
# Epoch 53/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 29433.1587 - mean_absolute_error: 78.0186 - val_loss: 30550.6491 - val_mean_absolute_error: 84.2353
# Epoch 54/1000
# 64/64 [==============================] - 24s 377ms/step - loss: 29439.8216 - mean_absolute_error: 77.9220 - val_loss: 32606.9219 - val_mean_absolute_error: 107.0647
# Epoch 55/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 30225.0230 - mean_absolute_error: 79.4748 - val_loss: 43461.6156 - val_mean_absolute_error: 152.0607
# Epoch 56/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 29191.7333 - mean_absolute_error: 78.5902 - val_loss: 32048.5850 - val_mean_absolute_error: 103.6002
# Epoch 57/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 29296.0995 - mean_absolute_error: 78.3388 - val_loss: 30533.6057 - val_mean_absolute_error: 87.7349
# Epoch 58/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 29259.7824 - mean_absolute_error: 77.3973 - val_loss: 31669.1500 - val_mean_absolute_error: 101.3514
# Epoch 59/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 29543.6549 - mean_absolute_error: 78.6687 - val_loss: 31882.5006 - val_mean_absolute_error: 101.4776
# Epoch 60/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 28694.8431 - mean_absolute_error: 75.3875 - val_loss: 33779.8228 - val_mean_absolute_error: 118.9990
# Epoch 61/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 29458.0548 - mean_absolute_error: 79.2253 - val_loss: 32374.7469 - val_mean_absolute_error: 90.6450
# Epoch 62/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 28597.7930 - mean_absolute_error: 77.7072 - val_loss: 30247.7041 - val_mean_absolute_error: 88.9520
# Epoch 63/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 28970.6828 - mean_absolute_error: 77.4081 - val_loss: 30411.3467 - val_mean_absolute_error: 84.8684
# Epoch 64/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 28723.2962 - mean_absolute_error: 77.3216 - val_loss: 29526.4570 - val_mean_absolute_error: 80.7214
# Epoch 65/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 28759.7886 - mean_absolute_error: 78.3481 - val_loss: 30117.3558 - val_mean_absolute_error: 89.5858
# Epoch 66/1000
# 64/64 [==============================] - 24s 373ms/step - loss: 28684.9918 - mean_absolute_error: 76.3426 - val_loss: 30981.4231 - val_mean_absolute_error: 100.5535
# Epoch 67/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 28376.1634 - mean_absolute_error: 74.8256 - val_loss: 29796.6825 - val_mean_absolute_error: 87.8545
# Epoch 68/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 28441.7858 - mean_absolute_error: 76.3875 - val_loss: 29596.7803 - val_mean_absolute_error: 83.2194
# Epoch 69/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 28202.6239 - mean_absolute_error: 74.7264 - val_loss: 29535.1419 - val_mean_absolute_error: 86.0652
# Epoch 70/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 29182.2612 - mean_absolute_error: 77.2922 - val_loss: 30727.2395 - val_mean_absolute_error: 100.2846
# Epoch 71/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 27586.6683 - mean_absolute_error: 72.5080 - val_loss: 29721.7820 - val_mean_absolute_error: 90.3159
# Epoch 72/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 28000.2869 - mean_absolute_error: 74.2225 - val_loss: 29515.0517 - val_mean_absolute_error: 84.2025
# Epoch 73/1000
# 64/64 [==============================] - 24s 377ms/step - loss: 27952.4535 - mean_absolute_error: 73.6934 - val_loss: 29388.4220 - val_mean_absolute_error: 88.3554
# Epoch 74/1000
# 64/64 [==============================] - 24s 373ms/step - loss: 27754.1280 - mean_absolute_error: 72.8950 - val_loss: 30905.3775 - val_mean_absolute_error: 101.2203
# Epoch 75/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 28052.8597 - mean_absolute_error: 75.5403 - val_loss: 28680.4819 - val_mean_absolute_error: 79.1014
# Epoch 76/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 27444.3497 - mean_absolute_error: 75.3375 - val_loss: 33630.3253 - val_mean_absolute_error: 126.0407
# Epoch 77/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 27744.5818 - mean_absolute_error: 75.1308 - val_loss: 29922.8644 - val_mean_absolute_error: 96.0692
# Epoch 78/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 27399.1884 - mean_absolute_error: 74.7269 - val_loss: 29811.9219 - val_mean_absolute_error: 85.5779
# Epoch 79/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 27766.9729 - mean_absolute_error: 74.8798 - val_loss: 30204.6669 - val_mean_absolute_error: 95.9055
# Epoch 80/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 27505.3709 - mean_absolute_error: 73.1832 - val_loss: 33613.8025 - val_mean_absolute_error: 126.7359
# Epoch 81/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 27054.7210 - mean_absolute_error: 72.7593 - val_loss: 28129.8262 - val_mean_absolute_error: 81.5967
# Epoch 82/1000
# 64/64 [==============================] - 24s 373ms/step - loss: 26894.9799 - mean_absolute_error: 71.6777 - val_loss: 28689.9094 - val_mean_absolute_error: 87.4224
# Epoch 83/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 27130.0336 - mean_absolute_error: 72.6225 - val_loss: 29126.3988 - val_mean_absolute_error: 92.3515
# Epoch 84/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 27423.5974 - mean_absolute_error: 72.7034 - val_loss: 28576.9644 - val_mean_absolute_error: 87.6553
# Epoch 85/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 26993.5594 - mean_absolute_error: 72.0604 - val_loss: 30925.4575 - val_mean_absolute_error: 102.9752
# Epoch 86/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 27221.7552 - mean_absolute_error: 72.4108 - val_loss: 28897.5844 - val_mean_absolute_error: 88.8367
# Epoch 87/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 26683.8291 - mean_absolute_error: 70.7218 - val_loss: 29235.1794 - val_mean_absolute_error: 94.4233
# Epoch 88/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 26244.4699 - mean_absolute_error: 70.0816 - val_loss: 29398.0544 - val_mean_absolute_error: 98.5085
# Epoch 89/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 27594.1528 - mean_absolute_error: 78.3296 - val_loss: 53946.1091 - val_mean_absolute_error: 204.9041
# Epoch 90/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 26647.4215 - mean_absolute_error: 74.7954 - val_loss: 33191.6475 - val_mean_absolute_error: 126.5411
# Epoch 91/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 26679.5552 - mean_absolute_error: 73.6377 - val_loss: 27963.4313 - val_mean_absolute_error: 79.6885
# Epoch 92/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 26173.3660 - mean_absolute_error: 71.4589 - val_loss: 30970.4892 - val_mean_absolute_error: 112.9218
# Epoch 93/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 26998.1828 - mean_absolute_error: 73.3010 - val_loss: 27998.2541 - val_mean_absolute_error: 88.8457
# Epoch 94/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 26022.1414 - mean_absolute_error: 71.9582 - val_loss: 26936.9722 - val_mean_absolute_error: 76.2852
# Epoch 95/1000
# 64/64 [==============================] - 24s 377ms/step - loss: 26231.2078 - mean_absolute_error: 72.1656 - val_loss: 28282.7136 - val_mean_absolute_error: 92.7878
# Epoch 96/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 25966.6562 - mean_absolute_error: 71.0331 - val_loss: 29639.0189 - val_mean_absolute_error: 105.8095
# Epoch 97/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 26504.8053 - mean_absolute_error: 72.5455 - val_loss: 27044.1950 - val_mean_absolute_error: 80.5950
# Epoch 98/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 25605.1876 - mean_absolute_error: 70.1788 - val_loss: 27852.2207 - val_mean_absolute_error: 89.0530
# Epoch 99/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 26119.8115 - mean_absolute_error: 70.5600 - val_loss: 29367.5945 - val_mean_absolute_error: 94.6767
# Epoch 100/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 25835.4343 - mean_absolute_error: 70.1001 - val_loss: 28947.8766 - val_mean_absolute_error: 102.0344
# Epoch 101/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 25002.1243 - mean_absolute_error: 67.4661 - val_loss: 26393.8778 - val_mean_absolute_error: 76.0630
# Epoch 102/1000
# 64/64 [==============================] - 25s 388ms/step - loss: 26419.3650 - mean_absolute_error: 71.6803 - val_loss: 29804.9106 - val_mean_absolute_error: 110.5504
# Epoch 103/1000
# 64/64 [==============================] - 24s 378ms/step - loss: 25137.0590 - mean_absolute_error: 68.3201 - val_loss: 26191.7533 - val_mean_absolute_error: 72.0536
# Epoch 104/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 25734.0491 - mean_absolute_error: 69.4944 - val_loss: 26033.6648 - val_mean_absolute_error: 70.9975
# Epoch 105/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 25436.4462 - mean_absolute_error: 68.4415 - val_loss: 29214.5245 - val_mean_absolute_error: 106.8782
# Epoch 106/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 25107.8023 - mean_absolute_error: 68.5999 - val_loss: 29212.0817 - val_mean_absolute_error: 107.4930
# Epoch 107/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 25362.6924 - mean_absolute_error: 69.6375 - val_loss: 27631.6616 - val_mean_absolute_error: 95.2100
# Epoch 108/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 24699.7857 - mean_absolute_error: 67.2693 - val_loss: 26538.8805 - val_mean_absolute_error: 82.8970
# Epoch 109/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 25707.1187 - mean_absolute_error: 69.7840 - val_loss: 28062.1825 - val_mean_absolute_error: 99.6884
# Epoch 110/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 24319.2939 - mean_absolute_error: 66.4595 - val_loss: 26170.0775 - val_mean_absolute_error: 80.1883
# Epoch 111/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 25024.2950 - mean_absolute_error: 69.2230 - val_loss: 27861.7825 - val_mean_absolute_error: 97.7282
# Epoch 112/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 25047.7163 - mean_absolute_error: 68.0864 - val_loss: 26792.5408 - val_mean_absolute_error: 88.7999
# Epoch 113/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 24857.8064 - mean_absolute_error: 67.9400 - val_loss: 25324.8767 - val_mean_absolute_error: 69.9768
# Epoch 114/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 24523.3898 - mean_absolute_error: 67.5265 - val_loss: 25201.5257 - val_mean_absolute_error: 68.2723
# Epoch 115/1000
# 64/64 [==============================] - 24s 377ms/step - loss: 24816.0156 - mean_absolute_error: 68.0989 - val_loss: 25169.0177 - val_mean_absolute_error: 72.0079
# Epoch 116/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 24259.2227 - mean_absolute_error: 66.6718 - val_loss: 26238.0539 - val_mean_absolute_error: 87.4429
# Epoch 117/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 24608.6975 - mean_absolute_error: 68.5342 - val_loss: 40243.4147 - val_mean_absolute_error: 106.9450
# Epoch 118/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 24579.5638 - mean_absolute_error: 68.0660 - val_loss: 26622.0747 - val_mean_absolute_error: 91.7472
# Epoch 119/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 23980.7806 - mean_absolute_error: 66.3976 - val_loss: 26646.9902 - val_mean_absolute_error: 92.5535
# Epoch 120/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 24043.8091 - mean_absolute_error: 66.9752 - val_loss: 25286.3678 - val_mean_absolute_error: 77.9713
# Epoch 121/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 24284.5356 - mean_absolute_error: 67.4553 - val_loss: 24834.9458 - val_mean_absolute_error: 70.5242
# Epoch 122/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 23981.4110 - mean_absolute_error: 65.9854 - val_loss: 26424.7670 - val_mean_absolute_error: 87.8782
# Epoch 123/1000
# 64/64 [==============================] - 24s 373ms/step - loss: 24199.0436 - mean_absolute_error: 67.2731 - val_loss: 25055.1689 - val_mean_absolute_error: 74.8400
# Epoch 124/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 23734.4459 - mean_absolute_error: 67.2470 - val_loss: 28280.1938 - val_mean_absolute_error: 102.8647
# Epoch 125/1000
# 64/64 [==============================] - 24s 377ms/step - loss: 23897.2926 - mean_absolute_error: 67.4595 - val_loss: 27239.4602 - val_mean_absolute_error: 101.9631
# Epoch 126/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 23797.6665 - mean_absolute_error: 68.2910 - val_loss: 24784.7895 - val_mean_absolute_error: 78.3013
# Epoch 127/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 23194.8013 - mean_absolute_error: 65.3577 - val_loss: 24489.8271 - val_mean_absolute_error: 72.6167
# Epoch 128/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 24037.9980 - mean_absolute_error: 68.4103 - val_loss: 25202.2244 - val_mean_absolute_error: 83.2162
# Epoch 129/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 23602.0261 - mean_absolute_error: 67.2206 - val_loss: 26086.8058 - val_mean_absolute_error: 93.2550
# Epoch 130/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 23286.3794 - mean_absolute_error: 65.6237 - val_loss: 30800.3216 - val_mean_absolute_error: 126.0517
# Epoch 131/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 23913.9077 - mean_absolute_error: 71.6903 - val_loss: 32274.8461 - val_mean_absolute_error: 132.1538
# Epoch 132/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 23675.0511 - mean_absolute_error: 70.7740 - val_loss: 29331.6859 - val_mean_absolute_error: 99.9171
# Epoch 133/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 23069.9759 - mean_absolute_error: 66.9199 - val_loss: 25495.6897 - val_mean_absolute_error: 92.1246
# Epoch 134/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 23979.4175 - mean_absolute_error: 69.2209 - val_loss: 24816.4392 - val_mean_absolute_error: 85.2212
# Epoch 135/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 22370.6168 - mean_absolute_error: 64.4646 - val_loss: 30784.5167 - val_mean_absolute_error: 128.1508
# Epoch 136/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 23853.0455 - mean_absolute_error: 67.1334 - val_loss: 35595.0739 - val_mean_absolute_error: 141.6482
# Epoch 137/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 22477.1759 - mean_absolute_error: 64.4483 - val_loss: 30880.2677 - val_mean_absolute_error: 128.1951
# Epoch 138/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 22868.4062 - mean_absolute_error: 65.6416 - val_loss: 46923.9275 - val_mean_absolute_error: 156.1552
# Epoch 139/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 23116.0682 - mean_absolute_error: 67.4611 - val_loss: 26334.2016 - val_mean_absolute_error: 96.2872
# Epoch 140/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 22960.6302 - mean_absolute_error: 69.4117 - val_loss: 27754.5913 - val_mean_absolute_error: 105.7220
# Epoch 141/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 22935.7419 - mean_absolute_error: 66.5297 - val_loss: 23216.7449 - val_mean_absolute_error: 67.6400
# Epoch 142/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 22565.3793 - mean_absolute_error: 66.1831 - val_loss: 25159.4124 - val_mean_absolute_error: 82.1621
# Epoch 143/1000
# 64/64 [==============================] - 24s 377ms/step - loss: 22265.2492 - mean_absolute_error: 65.0604 - val_loss: 30947.5041 - val_mean_absolute_error: 121.1606
# Epoch 144/1000
# 64/64 [==============================] - 24s 377ms/step - loss: 22483.7528 - mean_absolute_error: 64.4077 - val_loss: 32343.4644 - val_mean_absolute_error: 122.7816
# Epoch 145/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 22593.1847 - mean_absolute_error: 64.4221 - val_loss: 32442.2756 - val_mean_absolute_error: 120.2998
# Epoch 146/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 22010.7807 - mean_absolute_error: 64.3380 - val_loss: 36707.8167 - val_mean_absolute_error: 99.4847
# Epoch 147/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 22248.8038 - mean_absolute_error: 64.1862 - val_loss: 25567.4805 - val_mean_absolute_error: 96.0540
# Epoch 148/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 22289.9119 - mean_absolute_error: 64.9325 - val_loss: 32814.4634 - val_mean_absolute_error: 141.2066
# Epoch 149/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 22027.3678 - mean_absolute_error: 64.1128 - val_loss: 26112.1326 - val_mean_absolute_error: 105.0750
# Epoch 150/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 22044.5966 - mean_absolute_error: 64.0914 - val_loss: 26665.5384 - val_mean_absolute_error: 107.1843
# Epoch 151/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 21925.3633 - mean_absolute_error: 63.8767 - val_loss: 32494.3123 - val_mean_absolute_error: 109.7135
# Epoch 152/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 21868.7884 - mean_absolute_error: 63.2239 - val_loss: 31594.2594 - val_mean_absolute_error: 135.5894
# Epoch 153/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 21608.8584 - mean_absolute_error: 62.9979 - val_loss: 26608.7448 - val_mean_absolute_error: 102.2549
# Epoch 154/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 21689.8292 - mean_absolute_error: 63.8361 - val_loss: 211254.5081 - val_mean_absolute_error: 422.8425
# Epoch 155/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 21668.3592 - mean_absolute_error: 63.6318 - val_loss: 38648.9947 - val_mean_absolute_error: 90.3108
# Epoch 156/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 21721.6669 - mean_absolute_error: 64.1863 - val_loss: 29428.4409 - val_mean_absolute_error: 101.1992
# Epoch 157/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 21665.5400 - mean_absolute_error: 63.7443 - val_loss: 22669.5920 - val_mean_absolute_error: 78.2620
# Epoch 158/1000
# 64/64 [==============================] - 24s 377ms/step - loss: 20905.6851 - mean_absolute_error: 61.7980 - val_loss: 28994.9464 - val_mean_absolute_error: 124.5953
# Epoch 159/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 21772.7693 - mean_absolute_error: 63.6362 - val_loss: 30450.4803 - val_mean_absolute_error: 105.9722
# Epoch 160/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 21025.7087 - mean_absolute_error: 61.7315 - val_loss: 29509.9794 - val_mean_absolute_error: 109.3512
# Epoch 161/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 21583.5694 - mean_absolute_error: 63.0674 - val_loss: 134180.8575 - val_mean_absolute_error: 229.3154
# Epoch 162/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 20835.9587 - mean_absolute_error: 62.0755 - val_loss: 22304.1581 - val_mean_absolute_error: 75.6252
# Epoch 163/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 20978.5058 - mean_absolute_error: 62.0636 - val_loss: 22794.8181 - val_mean_absolute_error: 74.0508
# Epoch 164/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 20910.6830 - mean_absolute_error: 62.4035 - val_loss: 8595209.2600 - val_mean_absolute_error: 982.9267
# Epoch 165/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 21230.4301 - mean_absolute_error: 62.6452 - val_loss: 24566.8247 - val_mean_absolute_error: 98.8573
# Epoch 166/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 20603.1693 - mean_absolute_error: 61.6439 - val_loss: 23188.0595 - val_mean_absolute_error: 88.5080
# Epoch 167/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 20492.6601 - mean_absolute_error: 60.7343 - val_loss: 26763.5680 - val_mean_absolute_error: 79.1754
# Epoch 168/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 20952.3227 - mean_absolute_error: 62.7029 - val_loss: 21704.1161 - val_mean_absolute_error: 73.1479
# Epoch 169/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 20642.4644 - mean_absolute_error: 62.4618 - val_loss: 2310061309296.6401 - val_mean_absolute_error: 393788.1450
# Epoch 170/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 20507.9449 - mean_absolute_error: 61.4891 - val_loss: 21017.8158 - val_mean_absolute_error: 64.7220
# Epoch 171/1000
# 64/64 [==============================] - 24s 377ms/step - loss: 20411.4550 - mean_absolute_error: 60.9374 - val_loss: 23867.8021 - val_mean_absolute_error: 96.2977
# Epoch 172/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 20277.6750 - mean_absolute_error: 61.4141 - val_loss: 363330662.4000 - val_mean_absolute_error: 3227.8940
# Epoch 173/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 20308.5798 - mean_absolute_error: 63.4952 - val_loss: 193220.9731 - val_mean_absolute_error: 382.7698
# Epoch 174/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 20392.4599 - mean_absolute_error: 61.2766 - val_loss: 20982.2127 - val_mean_absolute_error: 67.5227
# Epoch 175/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 20218.4154 - mean_absolute_error: 62.3503 - val_loss: 31927.6473 - val_mean_absolute_error: 103.8416
# Epoch 176/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 20339.1001 - mean_absolute_error: 61.3574 - val_loss: 25989.4419 - val_mean_absolute_error: 105.3536
# Epoch 177/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 19997.7185 - mean_absolute_error: 59.9617 - val_loss: 28122.6602 - val_mean_absolute_error: 117.9261
# Epoch 178/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 20112.7267 - mean_absolute_error: 60.1992 - val_loss: 35004.4397 - val_mean_absolute_error: 139.3026
# Epoch 179/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 19851.5164 - mean_absolute_error: 60.4492 - val_loss: 28343.1041 - val_mean_absolute_error: 126.1065
# Epoch 180/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 19727.5469 - mean_absolute_error: 59.3441 - val_loss: 33257.0508 - val_mean_absolute_error: 124.2284
# Epoch 181/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 19700.3491 - mean_absolute_error: 59.1796 - val_loss: 27243.2819 - val_mean_absolute_error: 84.3383
# Epoch 182/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 19820.7397 - mean_absolute_error: 60.3567 - val_loss: 21089.9058 - val_mean_absolute_error: 75.8814
# Epoch 183/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 19616.2704 - mean_absolute_error: 59.8340 - val_loss: 22065.7555 - val_mean_absolute_error: 86.7140
# Epoch 184/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 19408.2993 - mean_absolute_error: 59.2901 - val_loss: 23219.0664 - val_mean_absolute_error: 97.1736
# Epoch 185/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 19504.2578 - mean_absolute_error: 59.2705 - val_loss: 21515.8730 - val_mean_absolute_error: 80.9697
# Epoch 186/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 19619.6882 - mean_absolute_error: 60.6895 - val_loss: 23548.9530 - val_mean_absolute_error: 99.9603
# Epoch 187/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 19327.8292 - mean_absolute_error: 61.3972 - val_loss: 288321.6738 - val_mean_absolute_error: 457.9494
# Epoch 188/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 19091.8407 - mean_absolute_error: 58.9400 - val_loss: 28112.0983 - val_mean_absolute_error: 85.8319
# Epoch 189/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 19208.1707 - mean_absolute_error: 58.9604 - val_loss: 38495.6747 - val_mean_absolute_error: 98.9000
# Epoch 190/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 19182.5110 - mean_absolute_error: 59.4797 - val_loss: 40072.7475 - val_mean_absolute_error: 121.5045
# Epoch 191/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 19656.4191 - mean_absolute_error: 60.8702 - val_loss: 43134.4180 - val_mean_absolute_error: 178.8327
# Epoch 192/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 19389.9960 - mean_absolute_error: 63.2312 - val_loss: 172436.5212 - val_mean_absolute_error: 368.1379
# Epoch 193/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 18853.0479 - mean_absolute_error: 64.5103 - val_loss: 20258.2624 - val_mean_absolute_error: 71.6621
# Epoch 194/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 18809.7927 - mean_absolute_error: 59.3002 - val_loss: 32631.9123 - val_mean_absolute_error: 147.1055
# Epoch 195/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 18715.9464 - mean_absolute_error: 59.5402 - val_loss: 64194.7228 - val_mean_absolute_error: 233.5544
# Epoch 196/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 18985.1831 - mean_absolute_error: 58.9584 - val_loss: 44748.9997 - val_mean_absolute_error: 166.0037
# Epoch 197/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 18833.5877 - mean_absolute_error: 59.1365 - val_loss: 65853.1644 - val_mean_absolute_error: 232.0905
# Epoch 198/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 19056.1623 - mean_absolute_error: 61.9855 - val_loss: 251563.2056 - val_mean_absolute_error: 394.5165
# Epoch 199/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 18811.1353 - mean_absolute_error: 63.3605 - val_loss: 289820.9075 - val_mean_absolute_error: 496.0836
# Epoch 200/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 18771.9617 - mean_absolute_error: 60.8940 - val_loss: 39588.9222 - val_mean_absolute_error: 146.1241
# Epoch 201/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 18627.3122 - mean_absolute_error: 59.5431 - val_loss: 36416.5786 - val_mean_absolute_error: 133.9843
# Epoch 202/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 18024.7428 - mean_absolute_error: 57.7121 - val_loss: 113515.5884 - val_mean_absolute_error: 314.7649
# Epoch 203/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 18515.2291 - mean_absolute_error: 59.3370 - val_loss: 99353.8613 - val_mean_absolute_error: 295.1688
# Epoch 204/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 18278.0800 - mean_absolute_error: 58.2916 - val_loss: 116795.0431 - val_mean_absolute_error: 318.8685
# Epoch 205/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 17981.0523 - mean_absolute_error: 57.0418 - val_loss: 23008.3824 - val_mean_absolute_error: 102.9021
# Epoch 206/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 17721.2338 - mean_absolute_error: 56.0722 - val_loss: 44373.1837 - val_mean_absolute_error: 159.7769
# Epoch 207/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 18360.1025 - mean_absolute_error: 57.7368 - val_loss: 34236.0891 - val_mean_absolute_error: 125.5844
# Epoch 208/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 18117.7959 - mean_absolute_error: 57.5909 - val_loss: 258978682.8800 - val_mean_absolute_error: 2596.9589
# Epoch 209/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 18390.2274 - mean_absolute_error: 59.0807 - val_loss: 258838497.2800 - val_mean_absolute_error: 2500.4793
# Epoch 210/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 17630.4424 - mean_absolute_error: 57.9462 - val_loss: 14427528.8000 - val_mean_absolute_error: 888.5984
# Epoch 211/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 17747.4625 - mean_absolute_error: 58.3230 - val_loss: 6275668336.6400 - val_mean_absolute_error: 4717.7348
# Epoch 212/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 17862.7969 - mean_absolute_error: 57.5935 - val_loss: 3279132.1500 - val_mean_absolute_error: 612.7204
# Epoch 213/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 17658.7926 - mean_absolute_error: 56.3934 - val_loss: 32974.1970 - val_mean_absolute_error: 80.8395
# Epoch 214/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 17536.7124 - mean_absolute_error: 55.9637 - val_loss: 33335.3303 - val_mean_absolute_error: 130.7474
# Epoch 215/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 17556.9649 - mean_absolute_error: 56.2937 - val_loss: 46427.7678 - val_mean_absolute_error: 177.9244
# Epoch 216/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 17502.1627 - mean_absolute_error: 56.1760 - val_loss: 105690.8819 - val_mean_absolute_error: 301.3421
# Epoch 217/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 17277.9131 - mean_absolute_error: 56.5505 - val_loss: 113684.0887 - val_mean_absolute_error: 306.2327
# Epoch 218/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 17049.8656 - mean_absolute_error: 55.7801 - val_loss: 119350.5031 - val_mean_absolute_error: 307.6718
# Epoch 219/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 17754.4212 - mean_absolute_error: 59.4969 - val_loss: 92904607.6800 - val_mean_absolute_error: 813.5486
# Epoch 220/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 17250.0074 - mean_absolute_error: 57.1738 - val_loss: 19688867.2000 - val_mean_absolute_error: 887.1285
# Epoch 221/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 17187.7526 - mean_absolute_error: 56.2186 - val_loss: 35182.1939 - val_mean_absolute_error: 114.6834
# Epoch 222/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 16927.8425 - mean_absolute_error: 55.7780 - val_loss: 18796.7623 - val_mean_absolute_error: 68.7642
# Epoch 223/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 17244.0696 - mean_absolute_error: 55.6284 - val_loss: 17408.9467 - val_mean_absolute_error: 57.2274
# Epoch 224/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 17324.7536 - mean_absolute_error: 56.9796 - val_loss: 17473.3036 - val_mean_absolute_error: 60.8673
# Epoch 225/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 16565.3038 - mean_absolute_error: 54.0824 - val_loss: 17961.3869 - val_mean_absolute_error: 68.0865
# Epoch 226/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 16804.5307 - mean_absolute_error: 54.7996 - val_loss: 18273.7980 - val_mean_absolute_error: 72.3622
# Epoch 227/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 17113.3298 - mean_absolute_error: 55.0214 - val_loss: 18348.5547 - val_mean_absolute_error: 73.5883
# Epoch 228/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 16715.7294 - mean_absolute_error: 55.2672 - val_loss: 18703.8170 - val_mean_absolute_error: 78.0201
# Epoch 229/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 16576.9292 - mean_absolute_error: 55.6232 - val_loss: 26252.5522 - val_mean_absolute_error: 84.3879
# Epoch 230/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 16984.3217 - mean_absolute_error: 55.9933 - val_loss: 18151.2678 - val_mean_absolute_error: 74.4505
# Epoch 231/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 16272.8776 - mean_absolute_error: 53.3528 - val_loss: 18668.0312 - val_mean_absolute_error: 77.3748
# Epoch 232/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 16393.2655 - mean_absolute_error: 54.1991 - val_loss: 18708.0127 - val_mean_absolute_error: 80.7741
# Epoch 233/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 16407.0861 - mean_absolute_error: 54.3312 - val_loss: 19268.1194 - val_mean_absolute_error: 86.3212
# Epoch 234/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 16490.6327 - mean_absolute_error: 54.9539 - val_loss: 20679.5894 - val_mean_absolute_error: 97.3452
# Epoch 235/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 16419.3351 - mean_absolute_error: 53.9653 - val_loss: 20477.8088 - val_mean_absolute_error: 96.3000
# Epoch 236/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 16210.5970 - mean_absolute_error: 53.3646 - val_loss: 20865.4961 - val_mean_absolute_error: 98.8938
# Epoch 237/1000
# 64/64 [==============================] - 24s 371ms/step - loss: 16269.6887 - mean_absolute_error: 53.7917 - val_loss: 21829.0880 - val_mean_absolute_error: 105.5863
# Epoch 238/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 16036.7709 - mean_absolute_error: 53.1481 - val_loss: 23259.2408 - val_mean_absolute_error: 114.0036
# Epoch 239/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 16162.8053 - mean_absolute_error: 53.1359 - val_loss: 24445.6452 - val_mean_absolute_error: 120.2458
# Epoch 240/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 15933.9335 - mean_absolute_error: 53.4196 - val_loss: 25718.9844 - val_mean_absolute_error: 125.9317
# Epoch 241/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 15800.2757 - mean_absolute_error: 52.9568 - val_loss: 30825.4577 - val_mean_absolute_error: 134.0656
# Epoch 242/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 16210.7712 - mean_absolute_error: 55.4339 - val_loss: 43615.4406 - val_mean_absolute_error: 152.9101
# Epoch 243/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 15447.4504 - mean_absolute_error: 52.3936 - val_loss: 109938.4525 - val_mean_absolute_error: 304.7739
# Epoch 244/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 15930.5418 - mean_absolute_error: 54.0401 - val_loss: 27042.9248 - val_mean_absolute_error: 106.4249
# Epoch 245/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 15842.1349 - mean_absolute_error: 55.1170 - val_loss: 20853.6206 - val_mean_absolute_error: 102.3001
# Epoch 246/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 15540.7217 - mean_absolute_error: 54.7150 - val_loss: 34799.6778 - val_mean_absolute_error: 163.7921
# Epoch 247/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 16152.2952 - mean_absolute_error: 57.0095 - val_loss: 41396.1972 - val_mean_absolute_error: 178.9174
# Epoch 248/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 15230.3653 - mean_absolute_error: 52.6435 - val_loss: 92690.2431 - val_mean_absolute_error: 283.6444
# Epoch 249/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 15532.5559 - mean_absolute_error: 53.6719 - val_loss: 52763.1869 - val_mean_absolute_error: 183.8202
# Epoch 250/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 15352.4379 - mean_absolute_error: 52.8311 - val_loss: 11037741.9200 - val_mean_absolute_error: 722.0228
# Epoch 251/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 15168.4685 - mean_absolute_error: 52.5912 - val_loss: 46621.9238 - val_mean_absolute_error: 138.7841
# Epoch 252/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 15410.6914 - mean_absolute_error: 53.0096 - val_loss: 25241.5494 - val_mean_absolute_error: 123.3854
# Epoch 253/1000
# 64/64 [==============================] - 24s 371ms/step - loss: 15204.5609 - mean_absolute_error: 52.6461 - val_loss: 125706.3663 - val_mean_absolute_error: 329.8707
# Epoch 254/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 15033.4990 - mean_absolute_error: 52.9840 - val_loss: 135222.2975 - val_mean_absolute_error: 339.9513
# Epoch 255/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 15000.4065 - mean_absolute_error: 52.7376 - val_loss: 133450.1631 - val_mean_absolute_error: 336.3495
# Epoch 256/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 15067.6493 - mean_absolute_error: 51.6340 - val_loss: 131578.3675 - val_mean_absolute_error: 333.5647
# Epoch 257/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 15573.2047 - mean_absolute_error: 59.5515 - val_loss: 1646961812.4800 - val_mean_absolute_error: 3669.5078
# Epoch 258/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 15486.4433 - mean_absolute_error: 59.5778 - val_loss: 218032197.7600 - val_mean_absolute_error: 876.4445
# Epoch 259/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 15120.9439 - mean_absolute_error: 55.8604 - val_loss: 26902.9709 - val_mean_absolute_error: 94.5793
# Epoch 260/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 14999.8062 - mean_absolute_error: 54.0433 - val_loss: 17296.9963 - val_mean_absolute_error: 74.1310
# Epoch 261/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 14761.6234 - mean_absolute_error: 52.8446 - val_loss: 15669.5920 - val_mean_absolute_error: 63.3952
# Epoch 262/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 14793.7764 - mean_absolute_error: 52.6200 - val_loss: 15175.7147 - val_mean_absolute_error: 57.4917
# Epoch 263/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 14822.6443 - mean_absolute_error: 52.3665 - val_loss: 15052.2127 - val_mean_absolute_error: 55.8863
# Epoch 264/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 14706.9173 - mean_absolute_error: 52.2970 - val_loss: 14899.4284 - val_mean_absolute_error: 52.6736
# Epoch 265/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 14364.7673 - mean_absolute_error: 51.3602 - val_loss: 14830.2030 - val_mean_absolute_error: 52.7807
# Epoch 266/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 14834.3356 - mean_absolute_error: 52.1147 - val_loss: 14750.4269 - val_mean_absolute_error: 51.6178
# Epoch 267/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 14322.0027 - mean_absolute_error: 50.9212 - val_loss: 14706.7036 - val_mean_absolute_error: 53.3618
# Epoch 268/1000
# ...
# Epoch 788/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 531.6931 - mean_absolute_error: 14.6364 - val_loss: inf - val_mean_absolute_error: 114129155730769199104.0000
# Epoch 789/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 534.6511 - mean_absolute_error: 14.9966 - val_loss: inf - val_mean_absolute_error: 364015357612049825792.0000
# Epoch 790/1000
# 64/64 [==============================] - 24s 371ms/step - loss: 553.5857 - mean_absolute_error: 15.9593 - val_loss: inf - val_mean_absolute_error: 212069203515065040896.0000
# Epoch 791/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 577.9774 - mean_absolute_error: 16.5001 - val_loss: 365937753371759957730394112.0000 - val_mean_absolute_error: 67542034308.8880
# Epoch 792/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 543.7061 - mean_absolute_error: 14.9013 - val_loss: inf - val_mean_absolute_error: 2256508771900469504.0000
# Epoch 793/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 534.2682 - mean_absolute_error: 14.3533 - val_loss: inf - val_mean_absolute_error: 663708339839336316928.0000
# Epoch 794/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 546.6268 - mean_absolute_error: 14.5587 - val_loss: inf - val_mean_absolute_error: 21257642559448199168.0000
# Epoch 795/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 507.8870 - mean_absolute_error: 14.0385 - val_loss: 847761041588548575778832384.0000 - val_mean_absolute_error: 211810711441.9403
# Epoch 796/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 490.8370 - mean_absolute_error: 13.5259 - val_loss: inf - val_mean_absolute_error: 33303725197113466880.0000
# Epoch 797/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 698.2587 - mean_absolute_error: 17.4563 - val_loss: inf - val_mean_absolute_error: 3171747610610858004054016.0000
# Epoch 798/1000
# 64/64 [==============================] - 24s 380ms/step - loss: 573.5626 - mean_absolute_error: 15.5041 - val_loss: inf - val_mean_absolute_error: 42258866338238421794816.0000
# Epoch 799/1000
# 64/64 [==============================] - 24s 380ms/step - loss: 495.5575 - mean_absolute_error: 13.6669 - val_loss: inf - val_mean_absolute_error: 787650046752851200.0000
# Epoch 800/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 499.3082 - mean_absolute_error: 13.8840 - val_loss: inf - val_mean_absolute_error: 51884993829134616.0000
# Epoch 801/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 474.1062 - mean_absolute_error: 13.4441 - val_loss: inf - val_mean_absolute_error: 26518382447946812.0000
# Epoch 802/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 591.2386 - mean_absolute_error: 15.3672 - val_loss: inf - val_mean_absolute_error: 2525126511897487714811904.0000
# Epoch 803/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 689.8047 - mean_absolute_error: 16.8468 - val_loss: inf - val_mean_absolute_error: 7051614751788854.0000
# Epoch 804/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 561.5950 - mean_absolute_error: 15.7859 - val_loss: inf - val_mean_absolute_error: 631045780570117.3750
# Epoch 805/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 507.2592 - mean_absolute_error: 14.6074 - val_loss: inf - val_mean_absolute_error: 4349627499728735.5000
# Epoch 806/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 458.6776 - mean_absolute_error: 13.1695 - val_loss: inf - val_mean_absolute_error: 359891210071643.0000
# Epoch 807/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 445.9014 - mean_absolute_error: 13.0081 - val_loss: inf - val_mean_absolute_error: 69041431560247368.0000
# Epoch 808/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 444.6018 - mean_absolute_error: 13.1537 - val_loss: inf - val_mean_absolute_error: 2628869427629896.5000
# Epoch 809/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 437.5545 - mean_absolute_error: 13.2632 - val_loss: 3938057964084285075881984.0000 - val_mean_absolute_error: 8548058168.4787
# Epoch 810/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 452.1142 - mean_absolute_error: 13.8109 - val_loss: inf - val_mean_absolute_error: 3503523322286004.5000
# Epoch 811/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 409.1313 - mean_absolute_error: 12.5306 - val_loss: inf - val_mean_absolute_error: 2164007008146170.2500
# Epoch 812/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 409.9817 - mean_absolute_error: 12.7802 - val_loss: 145497844114824502125264896.0000 - val_mean_absolute_error: 37244885656.0657
# Epoch 813/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 402.9613 - mean_absolute_error: 12.5227 - val_loss: inf - val_mean_absolute_error: 76508213340161984.0000
# Epoch 814/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 385.8365 - mean_absolute_error: 12.0785 - val_loss: 145286464392447455649595392.0000 - val_mean_absolute_error: 44902485315.4918
# Epoch 815/1000
# 64/64 [==============================] - 24s 377ms/step - loss: 374.9073 - mean_absolute_error: 11.7694 - val_loss: 156996274974975419977039872.0000 - val_mean_absolute_error: 63016391157.1888
# Epoch 816/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 372.4734 - mean_absolute_error: 11.7750 - val_loss: 695796204752657448976777216.0000 - val_mean_absolute_error: 105500078251.3074
# Epoch 817/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 360.5955 - mean_absolute_error: 11.4681 - val_loss: 561713236647306868459307008.0000 - val_mean_absolute_error: 86632995143.2389
# Epoch 818/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 362.5257 - mean_absolute_error: 11.4842 - val_loss: inf - val_mean_absolute_error: 40937442103437271040.0000
# Epoch 819/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 374.7533 - mean_absolute_error: 11.9091 - val_loss: 1675852017535829934516207616.0000 - val_mean_absolute_error: 200691630169.6436
# Epoch 820/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 390.2200 - mean_absolute_error: 12.6880 - val_loss: 694517669267691394380167380992.0000 - val_mean_absolute_error: 3276993609080.8818
# Epoch 821/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 408.7687 - mean_absolute_error: 12.7959 - val_loss: 2569323999590347177145139200.0000 - val_mean_absolute_error: 207703218842.9228
# Epoch 822/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 388.7392 - mean_absolute_error: 12.3905 - val_loss: 1971772966820523559253704704.0000 - val_mean_absolute_error: 189278466052.8133
# Epoch 823/1000
# 64/64 [==============================] - 24s 371ms/step - loss: 374.9298 - mean_absolute_error: 12.1308 - val_loss: 100061489962980545864400896.0000 - val_mean_absolute_error: 70927886707.1700
# Epoch 824/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 455.7989 - mean_absolute_error: 13.1403 - val_loss: inf - val_mean_absolute_error: 433374603112495255126016.0000
# Epoch 825/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 516.8726 - mean_absolute_error: 15.5815 - val_loss: inf - val_mean_absolute_error: 13350822637408919552.0000
# Epoch 826/1000
# 64/64 [==============================] - 24s 381ms/step - loss: 416.3566 - mean_absolute_error: 13.2304 - val_loss: 22119350684035487582201577472.0000 - val_mean_absolute_error: 497068199138.4523
# Epoch 827/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 361.1369 - mean_absolute_error: 11.9066 - val_loss: 11183819828716110528643072.0000 - val_mean_absolute_error: 9379318430.8101
# Epoch 828/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 354.5946 - mean_absolute_error: 11.8285 - val_loss: 5221072690366410925805666304.0000 - val_mean_absolute_error: 221481895211.6012
# Epoch 829/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 362.3920 - mean_absolute_error: 12.2849 - val_loss: 620653268125965408028460056576.0000 - val_mean_absolute_error: 2567794689317.5322
# Epoch 830/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 329.9173 - mean_absolute_error: 11.3603 - val_loss: 23840368404497714475266866151424.0000 - val_mean_absolute_error: 10579793493368.2520
# Epoch 831/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 332.6108 - mean_absolute_error: 11.3785 - val_loss: 249080863010103444742602752.0000 - val_mean_absolute_error: 66590213352.0583
# Epoch 832/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 318.3145 - mean_absolute_error: 11.0313 - val_loss: inf - val_mean_absolute_error: 71086781227201716224.0000
# Epoch 833/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 324.0506 - mean_absolute_error: 11.0738 - val_loss: inf - val_mean_absolute_error: 1703838754722607872.0000
# Epoch 834/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 324.9742 - mean_absolute_error: 11.0123 - val_loss: inf - val_mean_absolute_error: 982283717621804957696.0000
# Epoch 835/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 311.3254 - mean_absolute_error: 11.0750 - val_loss: inf - val_mean_absolute_error: 224178693650977920.0000
# Epoch 836/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 310.7192 - mean_absolute_error: 11.2437 - val_loss: inf - val_mean_absolute_error: 73017091893948432384.0000
# Epoch 837/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 288.0877 - mean_absolute_error: 10.4519 - val_loss: inf - val_mean_absolute_error: 1594603931716370038784.0000
# Epoch 838/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 294.5893 - mean_absolute_error: 10.7403 - val_loss: inf - val_mean_absolute_error: 386282206931977306112.0000
# Epoch 839/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 290.1074 - mean_absolute_error: 10.4859 - val_loss: inf - val_mean_absolute_error: 343623548294634799104.0000
# Epoch 840/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 279.5423 - mean_absolute_error: 10.4558 - val_loss: inf - val_mean_absolute_error: 1196543820957520232448.0000
# Epoch 841/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 270.5434 - mean_absolute_error: 9.9560 - val_loss: inf - val_mean_absolute_error: 1207144934464380731392.0000
# Epoch 842/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 288.1542 - mean_absolute_error: 10.9420 - val_loss: inf - val_mean_absolute_error: 3937991469686636150784.0000
# Epoch 843/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 262.1898 - mean_absolute_error: 9.6523 - val_loss: inf - val_mean_absolute_error: 581334682961638129664.0000
# Epoch 844/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 271.0655 - mean_absolute_error: 10.3739 - val_loss: inf - val_mean_absolute_error: 3855834643174811238400.0000
# Epoch 845/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 259.8271 - mean_absolute_error: 9.8588 - val_loss: inf - val_mean_absolute_error: 2039661716597165522944.0000
# Epoch 846/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 250.8393 - mean_absolute_error: 9.4298 - val_loss: inf - val_mean_absolute_error: 7719524284675745906688.0000
# Epoch 847/1000
# 64/64 [==============================] - 24s 371ms/step - loss: 242.7311 - mean_absolute_error: 9.3049 - val_loss: inf - val_mean_absolute_error: 32447436596951059005440.0000
# Epoch 848/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 238.3872 - mean_absolute_error: 9.1432 - val_loss: inf - val_mean_absolute_error: 355682341512711110656.0000
# Epoch 849/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 240.0884 - mean_absolute_error: 9.4012 - val_loss: inf - val_mean_absolute_error: 6982241070542783250432.0000
# Epoch 850/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 247.0423 - mean_absolute_error: 9.6102 - val_loss: inf - val_mean_absolute_error: 2735990638612882915328.0000
# Epoch 851/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 1099.8540 - mean_absolute_error: 16.9288 - val_loss: inf - val_mean_absolute_error: 7127092920238211072.0000
# Epoch 852/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 1101.2900 - mean_absolute_error: 21.4467 - val_loss: inf - val_mean_absolute_error: 3645252066827309.0000
# Epoch 853/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 667.3483 - mean_absolute_error: 17.6096 - val_loss: 197836915663546532823206396428288.0000 - val_mean_absolute_error: 204387253900318.7188
# Epoch 854/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 489.7185 - mean_absolute_error: 14.4237 - val_loss: inf - val_mean_absolute_error: 10761833193430076.0000
# Epoch 855/1000
# 64/64 [==============================] - 24s 377ms/step - loss: 1226.0047 - mean_absolute_error: 21.7430 - val_loss: inf - val_mean_absolute_error: 627087171080512602112.0000
# Epoch 856/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 561.6610 - mean_absolute_error: 16.4877 - val_loss: 1683984946571252648311175249920.0000 - val_mean_absolute_error: 5066316809049.9297
# Epoch 857/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 465.4321 - mean_absolute_error: 14.6204 - val_loss: 18689020520544020864172032.0000 - val_mean_absolute_error: 22494339253.3842
# Epoch 858/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 372.5633 - mean_absolute_error: 12.4445 - val_loss: 737336052804163131670528.0000 - val_mean_absolute_error: 4318645039.1958
# Epoch 859/1000
# 64/64 [==============================] - 24s 374ms/step - loss: 349.0113 - mean_absolute_error: 12.0451 - val_loss: 500429546907607884627968.0000 - val_mean_absolute_error: 3311361735.6376
# Epoch 860/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 355.1885 - mean_absolute_error: 12.7159 - val_loss: 306127456631781242961920.0000 - val_mean_absolute_error: 2582370461.4241
# Epoch 861/1000
# 64/64 [==============================] - 24s 376ms/step - loss: 321.4038 - mean_absolute_error: 11.7751 - val_loss: inf - val_mean_absolute_error: 1015897647207989.7500
# Epoch 862/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 309.1170 - mean_absolute_error: 11.4762 - val_loss: 2978881472074508978180063232.0000 - val_mean_absolute_error: 209609811237.9898
# Epoch 863/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 280.9079 - mean_absolute_error: 10.6954 - val_loss: 8805609730465.8906 - val_mean_absolute_error: 8640.4133
# Epoch 864/1000
# 64/64 [==============================] - 24s 372ms/step - loss: 273.1621 - mean_absolute_error: 10.6044 - val_loss: 7271662831757.8223 - val_mean_absolute_error: 5252.3314
# Epoch 865/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 259.4146 - mean_absolute_error: 10.1746 - val_loss: 110714013394170.7344 - val_mean_absolute_error: 28232.0668
# Epoch 866/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 278.2301 - mean_absolute_error: 10.6855 - val_loss: 708.2298 - val_mean_absolute_error: 22.0491
# Epoch 867/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 267.0081 - mean_absolute_error: 10.6152 - val_loss: 305550544737765.5000 - val_mean_absolute_error: 39819.9624
# Epoch 868/1000
# 64/64 [==============================] - 24s 375ms/step - loss: 255.8105 - mean_absolute_error: 10.3066 - val_loss: 24789708674996363721703424.0000 - val_mean_absolute_error: 11010014142.1513
# Epoch 869/1000
#  6/64 [=>............................] - ETA: 21s - loss: 235.9360 - mean_absolute_error: 8.9944Buffered data was truncated after reaching the output size limit.

# %%
#import pickle
#file_pickle = open('trainHistoryDict', 'wb') 
#pickle.dump(hist, file_pickle)
#file_pickle.close()

#model.load_weights('model1.h5')

print(hist.history.keys())

index = 0
fix, ax = plt.subplots(2,1, figsize=(20,8))
loss_train = hist.history['loss']
loss_val = hist.history['val_loss']
plt.yscale('log')
ax[0].plot(loss_train[0:100])
plt.yscale('log')
ax[1].plot(loss_val[0:100])

#image_batch, mask_batch = next(my_generator(train_images, train_labels, 5))
fix, ax = plt.subplots(20,3, figsize=(8,60))
for i in range(20):
    ax[i,0].imshow(train_images[i,:,:,0], cmap='gray')
    ax[i,1].imshow(train_labels[i,:,:,0], cmap='gray')
    temp = model.predict( np.expand_dims( np.expand_dims(train_images[i,:,:,0], axis = 0), axis = 3 ))
    ax[i,2].imshow(np.squeeze(temp), cmap='gray')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_absolute_error', 'loss', 'mean_absolute_error'])

# %% [markdown]
# # Test
# 798.0172-22.4618

# %%
model.load_weights('rfg_v3.h5')
#model.compile(Adam(lr = 0.01), loss='mean_squared_error', metrics=['mean_absolute_error'])

loss, acc = model.evaluate(test_images,test_labels)
print(loss)
print(acc)
fix, ax = plt.subplots(20,3, figsize=(8,60))
for i in range(20):    
    ax[i,0].imshow(test_images[i,:,:,0], cmap='gray')
    ax[i,1].imshow(test_labels[i,:,:,0], cmap='gray')
    temp = model.predict( np.expand_dims( np.expand_dims(test_images[i,:,:,0], axis = 0), axis = 3 ))
    ax[i,2].imshow(np.squeeze(temp), cmap='gray')
plt.show()
# Out:
# 200/200 [==============================] - 1s 4ms/step
# 220.352568359375
# 9.31566261291504
